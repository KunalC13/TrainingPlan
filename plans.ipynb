# %%
import pandas as pd
import json

def extract_training_plan_to_json(csv_file):
    # Load the CSV file
    df = pd.read_csv(csv_file)

    # List to store JSON results
    users_training_plans = []

    # Process each row in the DataFrame
    for _, row in df.iterrows():
        name = row["Name "]
        training_plan_text = row["Training_Plan"]

        # Parse the training plan text into structured data
        training_plan = parse_training_plan(training_plan_text)

        # Add the result to the list
        users_training_plans.append({
            "Name ": name,
            "TrainingPlan": training_plan
        })

    # Convert the list to JSON
    json_output = json.dumps(users_training_plans, indent=4)
    return json_output

def parse_training_plan(training_plan_text):
    # Split the plan into days
    lines = training_plan_text.splitlines()
    training_plan = []
    current_day = None

    for line in lines:
        if "Day" in line:
            # Start a new day
            current_day = {"Day": line.strip(), "Exercises": []}
            training_plan.append(current_day)
        elif current_day and ":" in line:
            # Parse exercise details
            parts = line.split(":")
            exercise_name = parts[0].strip()
            sets_reps = parts[1].strip()
            if "sets of" in sets_reps:
                sets_reps_parts = sets_reps.split("sets of")
                sets = int(sets_reps_parts[0].strip())
                reps = sets_reps_parts[1].strip().replace("reps", "").strip()
                current_day["Exercises"].append({
                    "Name": exercise_name,
                    "Sets": sets,
                    "Reps": reps
                })

    return training_plan

# %%
csv_file = "user_training_plans_without_rules.csv"  # Replace with your file name
json_output = extract_training_plan_to_json(csv_file)

# Write the JSON output to a file
with open("training_plans.json", "w") as json_file:
    json_file.write(json_output)

print("Training plans saved to training_plans.json")
# Out:
# Training plans saved to training_plans.json

# %%
import json
import pandas as pd
from tabulate import tabulate

def visualize_training_plan(json_file):
    # Load JSON data
    with open(json_file, "r") as file:
        data = json.load(file)
    
    # Iterate over each user's training plan
    for user in data:
        name = user["Name "]
        training_plan = user["TrainingPlan"]
        
        print(f"\n{'='*40}\nTraining Plan for {name}\n{'='*40}")
        
        # Create a list of rows for tabular display
        rows = []
        for day in training_plan:
            day_name = day["Day"]
            for exercise in day["Exercises"]:
                rows.append([day_name, exercise["Name"], exercise["Sets"], exercise["Reps"]])
        
        # Convert rows to DataFrame
        df = pd.DataFrame(rows, columns=["Day", "Exercise", "Sets", "Reps"])
        
        # Display the table
        print(tabulate(df, headers="keys", tablefmt="grid"))
        print("\n")  # Add spacing between users

# Example usage
json_file = "training_plans.json"  # Replace with your JSON file path
visualize_training_plan(json_file)
# Out:
# ========================================
# Training Plan for A
# ========================================
# +----+------------------------------+--------------------------------+--------+------------------+
# |    | Day                          | Exercise                       |   Sets | Reps             |
# +====+==============================+================================+========+==================+
# |  0 | **Day 1: Chest and Triceps** | 2. Barbell Bench Press         |      3 | 10-12            |
# +----+------------------------------+--------------------------------+--------+------------------+
# |  1 | **Day 1: Chest and Triceps** | 3. Incline Dumbbell Press      |      3 | 10-12  (per arm) |
# +----+------------------------------+--------------------------------+--------+------------------+
# |  2 | **Day 1: Chest and Triceps** | 4. Tricep Pushdowns            |      3 | 10-12  (per arm) |
# +----+------------------------------+--------------------------------+--------+------------------+
# |  3 | **Day 1: Chest and Triceps** | 5. Overhead Dumbbell Extension |      3 | 10-12            |
# +----+------------------------------+--------------------------------+--------+------------------+
# |  4 | **Day 2: Back and Biceps**   | 2. Deadlifts                   |      3 | 10-12            |
# +----+------------------------------+--------------------------------+--------+------------------+
# |  5 | **Day 2: Back and Biceps**   | 3. Bent-Over Barbell Rows      |      3 | 10-12  (per arm) |
# +----+------------------------------+--------------------------------+--------+------------------+
# |  6 | **Day 2: Back and Biceps**   | 4. Dumbbell Bicep Curls        |      3 | 10-12  (per arm) |
# +----+------------------------------+--------------------------------+--------+------------------+
# |  7 | **Day 2: Back and Biceps**   | 5. Hammer Curls                |      3 | 10-12  (per arm) |
# +----+------------------------------+--------------------------------+--------+------------------+
# |  8 | **Day 3: Legs**              | 2. Leg Press                   |      3 | 10-12            |
# +----+------------------------------+--------------------------------+--------+------------------+
# |  9 | **Day 3: Legs**              | 3. Romanian Deadlifts          |      3 | 10-12  (per leg) |
# +----+------------------------------+--------------------------------+--------+------------------+
# | 10 | **Day 3: Legs**              | 4. Leg Extensions              |      3 | 10-12  (per leg) |
# +----+------------------------------+--------------------------------+--------+------------------+
#
#
#
# ========================================
# Training Plan for B
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for C
# ========================================
# +----+-------------------------------------------------------------------+-------------------------+--------+--------------------------------------------+
# |    | Day                                                               | Exercise                |   Sets | Reps                                       |
# +====+===================================================================+=========================+========+============================================+
# |  0 | * **Day 1:** Full Body Workout (60 minutes)                       | - Squats                |      3 | 10-12                                      |
# +----+-------------------------------------------------------------------+-------------------------+--------+--------------------------------------------+
# |  1 | * **Day 1:** Full Body Workout (60 minutes)                       | - Leg Press             |      3 | 10-12                                      |
# +----+-------------------------------------------------------------------+-------------------------+--------+--------------------------------------------+
# |  2 | * **Day 1:** Full Body Workout (60 minutes)                       | - Single-Leg Extensions |      3 | 10-12  (per leg)                           |
# +----+-------------------------------------------------------------------+-------------------------+--------+--------------------------------------------+
# |  3 | * **Day 2:** Hip and Lower Back Workout (60 minutes)              | - Lat Pulldowns         |      3 | 10-12                                      |
# +----+-------------------------------------------------------------------+-------------------------+--------+--------------------------------------------+
# |  4 | * **Day 2:** Hip and Lower Back Workout (60 minutes)              | - Bench Press           |      3 | 10-12                                      |
# +----+-------------------------------------------------------------------+-------------------------+--------+--------------------------------------------+
# |  5 | * **Day 2:** Hip and Lower Back Workout (60 minutes)              | - Back Extensions       |      3 | 10-12                                      |
# +----+-------------------------------------------------------------------+-------------------------+--------+--------------------------------------------+
# |  6 | * **Day 3:** Cardio Day with Hip Abduction Exercises (60 minutes) | - Burpees               |      2 | 10-12  ( Hip abduction exercises included) |
# +----+-------------------------------------------------------------------+-------------------------+--------+--------------------------------------------+
#
#
#
# ========================================
# Training Plan for D
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for E
# ========================================
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# |    | Day                                                                 | Exercise        |   Sets | Reps   |
# +====+=====================================================================+=================+========+========+
# |  0 | **Day 1:** Back Squats (3 sets of 10-12 reps)                       | * Back Squats   |      3 | 10-12  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# |  1 | **Day 2:** Lat Pulldown and Bench Press (3 sets each of 10-12 reps) | * Lat Pulldown  |      3 | 10-12  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# |  2 | **Day 2:** Lat Pulldown and Bench Press (3 sets each of 10-12 reps) | * Bench Press   |      3 | 10-12  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# |  3 | **Day 3:** Deadlifts and Hip Abduction (2 sets each of 10-12 reps)  | * Deadlifts     |      2 | 10-12  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# |  4 | **Day 3:** Deadlifts and Hip Abduction (2 sets each of 10-12 reps)  | * Hip Abduction |      2 | 10-12  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# |  5 | **Day 4:** Rest Day**                                               | * Back Squats   |      3 | 10-12  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# |  6 | **Day 4:** Rest Day**                                               | * Deadlifts     |      2 | 10-12  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# |  7 | **Day 4:** Rest Day**                                               | * Hip Abduction |      2 | 10-12  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# |  8 | **Day 4:** Rest Day**                                               | * Back Squats   |      3 | 12-15  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# |  9 | **Day 4:** Rest Day**                                               | * Deadlifts     |      2 | 12-15  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# | 10 | **Day 4:** Rest Day**                                               | * Hip Abduction |      2 | 12-15  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# | 11 | **Day 4:** Rest Day**                                               | * Back Squats   |      3 | 15-18  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# | 12 | **Day 4:** Rest Day**                                               | * Deadlifts     |      2 | 15-18  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# | 13 | **Day 4:** Rest Day**                                               | * Hip Abduction |      2 | 15-18  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# | 14 | **Day 4:** Rest Day**                                               | * Back Squats   |      3 | 18-20  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# | 15 | **Day 4:** Rest Day**                                               | * Deadlifts     |      2 | 18-20  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
# | 16 | **Day 4:** Rest Day**                                               | * Hip Abduction |      2 | 18-20  |
# +----+---------------------------------------------------------------------+-----------------+--------+--------+
#
#
#
# ========================================
# Training Plan for G
# ========================================
# +----+-------------+-------------------------------------+--------+----------------+
# |    | Day         | Exercise                            |   Sets | Reps           |
# +====+=============+=====================================+========+================+
# |  0 | * **Day 1** | + Back Squats                       |      3 | 10-12          |
# +----+-------------+-------------------------------------+--------+----------------+
# |  1 | * **Day 1** | + Leg Press                         |      3 | 10-12          |
# +----+-------------+-------------------------------------+--------+----------------+
# |  2 | * **Day 1** | + Single-Leg Deadlifts              |      2 | 10-12  per leg |
# +----+-------------+-------------------------------------+--------+----------------+
# |  3 | * **Day 2** | + Lat Pulldown                      |      3 | 10-12          |
# +----+-------------+-------------------------------------+--------+----------------+
# |  4 | * **Day 2** | + Bench Press                       |      3 | 10-12          |
# +----+-------------+-------------------------------------+--------+----------------+
# |  5 | * **Day 2** | + Back Extensions (seated row)      |      3 | 10-12          |
# +----+-------------+-------------------------------------+--------+----------------+
# |  6 | * **Day 4** | + Deadlifts                         |      3 | 10-12          |
# +----+-------------+-------------------------------------+--------+----------------+
# |  7 | * **Day 4** | + Leg Press                         |      3 | 10-12          |
# +----+-------------+-------------------------------------+--------+----------------+
# |  8 | * **Day 4** | + Hip Abductions (seated leg press) |      2 | 10-12  per leg |
# +----+-------------+-------------------------------------+--------+----------------+
# |  9 | * **Day 1** | + Back Squats                       |      4 | 8-10           |
# +----+-------------+-------------------------------------+--------+----------------+
# | 10 | * **Day 1** | + Leg Press                         |      3 | 9-11           |
# +----+-------------+-------------------------------------+--------+----------------+
# | 11 | * **Day 1** | + Single-Leg Deadlifts              |      2 | 8-10  per leg  |
# +----+-------------+-------------------------------------+--------+----------------+
# | 12 | * **Day 2** | + Lat Pulldown                      |      4 | 8-10           |
# +----+-------------+-------------------------------------+--------+----------------+
# | 13 | * **Day 2** | + Bench Press                       |      4 | 8-10           |
# +----+-------------+-------------------------------------+--------+----------------+
# | 14 | * **Day 2** | + Back Extensions (seated row)      |      3 | 8-10           |
# +----+-------------+-------------------------------------+--------+----------------+
# | 15 | * **Day 4** | + Deadlifts                         |      4 | 8-10           |
# +----+-------------+-------------------------------------+--------+----------------+
# | 16 | * **Day 4** | + Leg Press                         |      3 | 9-11           |
# +----+-------------+-------------------------------------+--------+----------------+
# | 17 | * **Day 4** | + Hip Abductions (seated leg press) |      2 | 8-10  per leg  |
# +----+-------------+-------------------------------------+--------+----------------+
# | 18 | * **Day 1** | + Back Squats                       |      5 | 6-8            |
# +----+-------------+-------------------------------------+--------+----------------+
# | 19 | * **Day 1** | + Leg Press                         |      4 | 7-9            |
# +----+-------------+-------------------------------------+--------+----------------+
# | 20 | * **Day 1** | + Single-Leg Deadlifts              |      3 | 6-8  per leg   |
# +----+-------------+-------------------------------------+--------+----------------+
# | 21 | * **Day 2** | + Lat Pulldown                      |      5 | 6-8            |
# +----+-------------+-------------------------------------+--------+----------------+
# | 22 | * **Day 2** | + Bench Press                       |      5 | 6-8            |
# +----+-------------+-------------------------------------+--------+----------------+
# | 23 | * **Day 2** | + Back Extensions (seated row)      |      4 | 6-8            |
# +----+-------------+-------------------------------------+--------+----------------+
# | 24 | * **Day 4** | + Deadlifts                         |      5 | 6-8            |
# +----+-------------+-------------------------------------+--------+----------------+
# | 25 | * **Day 4** | + Leg Press                         |      4 | 7-9            |
# +----+-------------+-------------------------------------+--------+----------------+
# | 26 | * **Day 4** | + Hip Abductions (seated leg press) |      2 | 6-8  per leg   |
# +----+-------------+-------------------------------------+--------+----------------+
#
#
#
# ========================================
# Training Plan for Sohini
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Kartikey
# ========================================
# +----+----------+-----------------+--------+------------------+
# |    | Day      | Exercise        |   Sets | Reps             |
# +====+==========+=================+========+==================+
# |  0 | * Day 1: | + Squats        |      3 | 10-12            |
# +----+----------+-----------------+--------+------------------+
# |  1 | * Day 1: | + Leg Press     |      3 | 10-12            |
# +----+----------+-----------------+--------+------------------+
# |  2 | * Day 1: | + Lunges        |      2 | 10-12  (per leg) |
# +----+----------+-----------------+--------+------------------+
# |  3 | * Day 2: | + Lat Pulldowns |      3 | 10-12            |
# +----+----------+-----------------+--------+------------------+
# |  4 | * Day 2: | + Bench Press   |      3 | 10-12            |
# +----+----------+-----------------+--------+------------------+
# |  5 | * Day 2: | + Seated Row    |      2 | 10-12            |
# +----+----------+-----------------+--------+------------------+
# |  6 | * Day 3: | + Deadlifts     |      3 | 10-12            |
# +----+----------+-----------------+--------+------------------+
# |  7 | * Day 3: | + Leg Press     |      3 | 10-12            |
# +----+----------+-----------------+--------+------------------+
# |  8 | * Day 3: | + Hip Abduction |      2 | 10-12            |
# +----+----------+-----------------+--------+------------------+
# |  9 | * Day 1: | + Squats        |      3 | 8-10             |
# +----+----------+-----------------+--------+------------------+
# | 10 | * Day 1: | + Leg Press     |      3 | 8-10             |
# +----+----------+-----------------+--------+------------------+
# | 11 | * Day 1: | + Lunges        |      2 | 8-10  (per leg)  |
# +----+----------+-----------------+--------+------------------+
# | 12 | * Day 2: | + Lat Pulldowns |      3 | 8-10             |
# +----+----------+-----------------+--------+------------------+
# | 13 | * Day 2: | + Bench Press   |      3 | 8-10             |
# +----+----------+-----------------+--------+------------------+
# | 14 | * Day 2: | + Seated Row    |      2 | 8-10             |
# +----+----------+-----------------+--------+------------------+
# | 15 | * Day 3: | + Deadlifts     |      3 | 8-10             |
# +----+----------+-----------------+--------+------------------+
# | 16 | * Day 3: | + Leg Press     |      3 | 8-10             |
# +----+----------+-----------------+--------+------------------+
# | 17 | * Day 3: | + Hip Abduction |      2 | 8-10             |
# +----+----------+-----------------+--------+------------------+
# | 18 | * Day 1: | + Squats        |      4 | 6-8              |
# +----+----------+-----------------+--------+------------------+
# | 19 | * Day 1: | + Leg Press     |      4 | 6-8              |
# +----+----------+-----------------+--------+------------------+
# | 20 | * Day 1: | + Lunges        |      3 | 6-8  (per leg)   |
# +----+----------+-----------------+--------+------------------+
# | 21 | * Day 2: | + Lat Pulldowns |      4 | 6-8              |
# +----+----------+-----------------+--------+------------------+
# | 22 | * Day 2: | + Bench Press   |      4 | 6-8              |
# +----+----------+-----------------+--------+------------------+
# | 23 | * Day 2: | + Seated Row    |      3 | 6-8              |
# +----+----------+-----------------+--------+------------------+
# | 24 | * Day 3: | + Deadlifts     |      4 | 6-8              |
# +----+----------+-----------------+--------+------------------+
# | 25 | * Day 3: | + Leg Press     |      4 | 6-8              |
# +----+----------+-----------------+--------+------------------+
# | 26 | * Day 3: | + Hip Abduction |      3 | 6-8              |
# +----+----------+-----------------+--------+------------------+
# | 27 | * Day 1: | + Squats        |      5 | 4-6              |
# +----+----------+-----------------+--------+------------------+
# | 28 | * Day 1: | + Leg Press     |      5 | 4-6              |
# +----+----------+-----------------+--------+------------------+
# | 29 | * Day 1: | + Lunges        |      3 | 4-6  (per leg)   |
# +----+----------+-----------------+--------+------------------+
# | 30 | * Day 2: | + Lat Pulldowns |      5 | 4-6              |
# +----+----------+-----------------+--------+------------------+
# | 31 | * Day 2: | + Bench Press   |      5 | 4-6              |
# +----+----------+-----------------+--------+------------------+
# | 32 | * Day 2: | + Seated Row    |      3 | 4-6              |
# +----+----------+-----------------+--------+------------------+
# | 33 | * Day 3: | + Deadlifts     |      5 | 4-6              |
# +----+----------+-----------------+--------+------------------+
# | 34 | * Day 3: | + Leg Press     |      5 | 4-6              |
# +----+----------+-----------------+--------+------------------+
# | 35 | * Day 3: | + Hip Abduction |      3 | 4-6              |
# +----+----------+-----------------+--------+------------------+
#
#
#
# ========================================
# Training Plan for Shivaksh Sharma
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Justyna
# ========================================
# +----+-------------+-------------------------+--------+------------------+
# |    | Day         | Exercise                |   Sets | Reps             |
# +====+=============+=========================+========+==================+
# |  0 | * **Day 1** | + Back Squats           |      3 | 10-12            |
# +----+-------------+-------------------------+--------+------------------+
# |  1 | * **Day 1** | + Leg Press             |      3 | 10-12            |
# +----+-------------+-------------------------+--------+------------------+
# |  2 | * **Day 1** | + Single Leg Extensions |      3 | 10-12  (per leg) |
# +----+-------------+-------------------------+--------+------------------+
# |  3 | * **Day 2** | + Lat Pulldown          |      3 | 10-12            |
# +----+-------------+-------------------------+--------+------------------+
# |  4 | * **Day 2** | + Bench Press           |      3 | 10-12            |
# +----+-------------+-------------------------+--------+------------------+
# |  5 | * **Day 2** | + Back Extensions       |      3 | 10-12            |
# +----+-------------+-------------------------+--------+------------------+
# |  6 | * **Day 3** | + Deadlifts             |      3 | 10-12            |
# +----+-------------+-------------------------+--------+------------------+
# |  7 | * **Day 3** | + Leg Press             |      2 | 10-12  (per leg) |
# +----+-------------+-------------------------+--------+------------------+
# |  8 | * **Day 3** | + Hip Abductions        |      2 | 10-12            |
# +----+-------------+-------------------------+--------+------------------+
# |  9 | * **Day 1** | + Back Squats           |      3 | 12-15            |
# +----+-------------+-------------------------+--------+------------------+
# | 10 | * **Day 1** | + Leg Press             |      3 | 12-15            |
# +----+-------------+-------------------------+--------+------------------+
# | 11 | * **Day 1** | + Single Leg Extensions |      3 | 12-15  (per leg) |
# +----+-------------+-------------------------+--------+------------------+
# | 12 | * **Day 2** | + Lat Pulldown          |      3 | 12-15            |
# +----+-------------+-------------------------+--------+------------------+
# | 13 | * **Day 2** | + Bench Press           |      3 | 12-15            |
# +----+-------------+-------------------------+--------+------------------+
# | 14 | * **Day 2** | + Back Extensions       |      3 | 12-15            |
# +----+-------------+-------------------------+--------+------------------+
# | 15 | * **Day 3** | + Deadlifts             |      2 | 15-20            |
# +----+-------------+-------------------------+--------+------------------+
# | 16 | * **Day 3** | + Leg Press             |      2 | 15-20            |
# +----+-------------+-------------------------+--------+------------------+
# | 17 | * **Day 3** | + Hip Abductions        |      2 | 15-20            |
# +----+-------------+-------------------------+--------+------------------+
# | 18 | * **Day 1** | + Back Squats           |      4 | 8-10             |
# +----+-------------+-------------------------+--------+------------------+
# | 19 | * **Day 1** | + Leg Press             |      4 | 8-10             |
# +----+-------------+-------------------------+--------+------------------+
# | 20 | * **Day 1** | + Single Leg Extensions |      3 | 8-10  (per leg)  |
# +----+-------------+-------------------------+--------+------------------+
# | 21 | * **Day 2** | + Lat Pulldown          |      3 | 8-10             |
# +----+-------------+-------------------------+--------+------------------+
# | 22 | * **Day 2** | + Bench Press           |      4 | 8-10             |
# +----+-------------+-------------------------+--------+------------------+
# | 23 | * **Day 2** | + Back Extensions       |      3 | 8-10             |
# +----+-------------+-------------------------+--------+------------------+
# | 24 | * **Day 3** | + Deadlifts             |      2 | 12-15            |
# +----+-------------+-------------------------+--------+------------------+
# | 25 | * **Day 3** | + Leg Press             |      2 | 12-15            |
# +----+-------------+-------------------------+--------+------------------+
# | 26 | * **Day 3** | + Hip Abductions        |      2 | 12-15            |
# +----+-------------+-------------------------+--------+------------------+
# | 27 | * **Day 1** | + Back Squats           |      3 | 10-12            |
# +----+-------------+-------------------------+--------+------------------+
# | 28 | * **Day 1** | + Leg Press             |      3 | 10-12            |
# +----+-------------+-------------------------+--------+------------------+
# | 29 | * **Day 1** | + Single Leg Extensions |      3 | 10-12  (per leg) |
# +----+-------------+-------------------------+--------+------------------+
# | 30 | * **Day 2** | + Lat Pulldown          |      3 | 8-10             |
# +----+-------------+-------------------------+--------+------------------+
# | 31 | * **Day 2** | + Bench Press           |      4 | 6-8              |
# +----+-------------+-------------------------+--------+------------------+
# | 32 | * **Day 2** | + Back Extensions       |      3 | 8-10             |
# +----+-------------+-------------------------+--------+------------------+
# | 33 | * **Day 3** | + Deadlifts             |      2 | 15-20            |
# +----+-------------+-------------------------+--------+------------------+
# | 34 | * **Day 3** | + Leg Press             |      2 | 15-20            |
# +----+-------------+-------------------------+--------+------------------+
# | 35 | * **Day 3** | + Hip Abductions        |      2 | 15-20            |
# +----+-------------+-------------------------+--------+------------------+
#
#
#
# ========================================
# Training Plan for Florida Ahmed
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Shrenik Vaidya
# ========================================
# +----+------------------------------+------------------------------------+--------+----------------------+
# |    | Day                          | Exercise                           |   Sets | Reps                 |
# +====+==============================+====================================+========+======================+
# |  0 | **Day 1: Chest and Triceps** | 2. Barbell Bench Press             |      3 | 8-12                 |
# +----+------------------------------+------------------------------------+--------+----------------------+
# |  1 | **Day 1: Chest and Triceps** | 3. Incline Dumbbell Press          |      3 | 10-15                |
# +----+------------------------------+------------------------------------+--------+----------------------+
# |  2 | **Day 1: Chest and Triceps** | 4. Tricep Pushdown                 |      3 | 10-12                |
# +----+------------------------------+------------------------------------+--------+----------------------+
# |  3 | **Day 1: Chest and Triceps** | 5. Overhead Dumbbell Extension     |      3 | 12-15                |
# +----+------------------------------+------------------------------------+--------+----------------------+
# |  4 | **Day 2: Back and Biceps**   | 2. Pull-ups (or Assisted Pull-ups) |      3 | as many  as possible |
# +----+------------------------------+------------------------------------+--------+----------------------+
# |  5 | **Day 2: Back and Biceps**   | 3. Barbell Rows                    |      3 | 8-12                 |
# +----+------------------------------+------------------------------------+--------+----------------------+
# |  6 | **Day 2: Back and Biceps**   | 4. Dumbbell Bicep Curls            |      3 | 10-12                |
# +----+------------------------------+------------------------------------+--------+----------------------+
# |  7 | **Day 2: Back and Biceps**   | 5. Hammer Curls (with dumbbells)   |      3 | 10-12                |
# +----+------------------------------+------------------------------------+--------+----------------------+
# |  8 | **Day 3: Legs**              | 2. Squats                          |      3 | 8-12                 |
# +----+------------------------------+------------------------------------+--------+----------------------+
# |  9 | **Day 3: Legs**              | 3. Leg Press                       |      3 | 10-12                |
# +----+------------------------------+------------------------------------+--------+----------------------+
# | 10 | **Day 3: Legs**              | 4. Lunges                          |      3 | 10-12  (per leg)     |
# +----+------------------------------+------------------------------------+--------+----------------------+
# | 11 | **Day 3: Legs**              | 5. Leg Extensions                  |      3 | 12-15                |
# +----+------------------------------+------------------------------------+--------+----------------------+
# | 12 | **Day 4: Shoulders and Abs** | 2. Seated Dumbbell Shoulder Press  |      3 | 8-12                 |
# +----+------------------------------+------------------------------------+--------+----------------------+
# | 13 | **Day 4: Shoulders and Abs** | 3. Lateral Raises                  |      3 | 10-12                |
# +----+------------------------------+------------------------------------+--------+----------------------+
# | 14 | **Day 4: Shoulders and Abs** | 4. Reverse Fly (with dumbbells)    |      3 | 12-15                |
# +----+------------------------------+------------------------------------+--------+----------------------+
# | 15 | **Day 4: Shoulders and Abs** | 6. Russian Twists (with dumbbells) |      3 | 10-12                |
# +----+------------------------------+------------------------------------+--------+----------------------+
#
#
#
# ========================================
# Training Plan for Katarzyna
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for F
# ========================================
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# |    | Day                                    | Exercise                                               |   Sets | Reps            |
# +====+========================================+========================================================+========+=================+
# |  0 | **Day 1: Full Body (Strength Focus)**  | * Squats                                               |      3 | 10-12           |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# |  1 | **Day 1: Full Body (Strength Focus)**  | * Deadlifts                                            |      3 | 10-12           |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# |  2 | **Day 1: Full Body (Strength Focus)**  | * Bench Press                                          |      3 | 10-12           |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# |  3 | **Day 1: Full Body (Strength Focus)**  | * Leg Press                                            |      3 | 10-12           |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# |  4 | **Day 1: Full Body (Strength Focus)**  | * Glute Bridges                                        |      2 | 10-12           |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# |  5 | **Day 1: Full Body (Strength Focus)**  | * Russian twists (light weights)                       |      2 | 10-12  per side |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# |  6 | **Day 2: Core Focus**                  | * Russian twists (light weights)                       |      3 | 12  per side    |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# |  7 | **Day 2: Core Focus**                  | * Leg raises (hanging leg raise machine or bodyweight) |      3 | 10-12           |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# |  8 | **Day 2: Core Focus**                  | * Bicycle crunches                                     |      3 | 10-12           |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# |  9 | **Day 2: Core Focus**                  | * Woodchoppers (light weights)                         |      2 | 12  per side    |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# | 10 | **Day 3: Glutes Focus**                | * Deadlifts                                            |      3 | 10-12           |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# | 11 | **Day 3: Glutes Focus**                | * Hip Abduction                                        |      2 | 10-12  per leg  |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# | 12 | **Day 3: Glutes Focus**                | * Glute Bridges                                        |      2 | 10-12           |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# | 13 | **Day 3: Glutes Focus**                | * Step-ups (using a low step or bench)                 |      2 | 10-12  per leg  |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# | 14 | **Day 4: Full Body (Endurance Focus)** | * Burpees                                              |      3 | 8-10            |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# | 15 | **Day 4: Full Body (Endurance Focus)** | * Mountain climbers                                    |      3 | 30-60 seconds   |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# | 16 | **Day 4: Full Body (Endurance Focus)** | * Jumping lunges                                       |      2 | 10-12  per leg  |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
# | 17 | **Day 4: Full Body (Endurance Focus)** | * Squat jumps                                          |      2 | 10-12           |
# +----+----------------------------------------+--------------------------------------------------------+--------+-----------------+
#
#
#
# ========================================
# Training Plan for H
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Mafalda Marques
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Shruti
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Jacek
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Sanju Nagar
# ========================================
# +----+-----------+----------------------+--------+----------------+
# |    | Day       | Exercise             |   Sets | Reps           |
# +====+===========+======================+========+================+
# |  0 | **Day 1** | + **Back Squats**    |      3 | 10-12          |
# +----+-----------+----------------------+--------+----------------+
# |  1 | **Day 1** | + **Leg Press**      |      3 | 10-12          |
# +----+-----------+----------------------+--------+----------------+
# |  2 | **Day 1** | + **Single Leg Ext** |      3 | 10-12  per leg |
# +----+-----------+----------------------+--------+----------------+
# |  3 | **Day 2** | + **Lat Pulldown**   |      3 | 10-12          |
# +----+-----------+----------------------+--------+----------------+
# |  4 | **Day 2** | + **Bench Press**    |      3 | 10-12          |
# +----+-----------+----------------------+--------+----------------+
# |  5 | **Day 2** | + **Back Ext**       |      3 | 10-12          |
# +----+-----------+----------------------+--------+----------------+
# |  6 | **Day 2** | + **Hip Abduction**  |      2 | 10-12  per leg |
# +----+-----------+----------------------+--------+----------------+
# |  7 | **Day 3** | + **Deadlifts**      |      3 | 10-12          |
# +----+-----------+----------------------+--------+----------------+
# |  8 | **Day 3** | + **Leg Press**      |      3 | 10-12          |
# +----+-----------+----------------------+--------+----------------+
# |  9 | **Day 3** | + **Hip Abduction**  |      2 | 10-12  per leg |
# +----+-----------+----------------------+--------+----------------+
#
#
#
# ========================================
# Training Plan for I
# ========================================
# +----+-------------+------------------+--------+-------------------+
# |    | Day         | Exercise         |   Sets | Reps              |
# +====+=============+==================+========+===================+
# |  0 | * **Day 1** | + Back Squats    |      3 | 10-12             |
# +----+-------------+------------------+--------+-------------------+
# |  1 | * **Day 1** | + Leg Press      |      3 | 10-12             |
# +----+-------------+------------------+--------+-------------------+
# |  2 | * **Day 1** | + Single Leg Ext |      3 | 10-12  (per leg)  |
# +----+-------------+------------------+--------+-------------------+
# |  3 | * **Day 2** | + Lat Pulldown   |      3 | 10-12             |
# +----+-------------+------------------+--------+-------------------+
# |  4 | * **Day 2** | + Bench Press    |      3 | 10-12             |
# +----+-------------+------------------+--------+-------------------+
# |  5 | * **Day 2** | + Back Ext       |      3 | 10-12  (per side) |
# +----+-------------+------------------+--------+-------------------+
# |  6 | * **Day 3** | + Deadlifts      |      3 | 10-12             |
# +----+-------------+------------------+--------+-------------------+
# |  7 | * **Day 3** | + Leg Press      |      2 | 10-12  (per leg)  |
# +----+-------------+------------------+--------+-------------------+
# |  8 | * **Day 1** | + Back Squats    |      3 | 12-15             |
# +----+-------------+------------------+--------+-------------------+
# |  9 | * **Day 1** | + Leg Press      |      3 | 12-15             |
# +----+-------------+------------------+--------+-------------------+
# | 10 | * **Day 1** | + Single Leg Ext |      2 | 12-15  (per leg)  |
# +----+-------------+------------------+--------+-------------------+
# | 11 | * **Day 2** | + Lat Pulldown   |      3 | 12-15             |
# +----+-------------+------------------+--------+-------------------+
# | 12 | * **Day 2** | + Bench Press    |      3 | 12-15             |
# +----+-------------+------------------+--------+-------------------+
# | 13 | * **Day 2** | + Back Ext       |      3 | 12-15  (per side) |
# +----+-------------+------------------+--------+-------------------+
# | 14 | * **Day 3** | + Deadlifts      |      2 | 12-15             |
# +----+-------------+------------------+--------+-------------------+
# | 15 | * **Day 3** | + Leg Press      |      2 | 12-15             |
# +----+-------------+------------------+--------+-------------------+
# | 16 | * **Day 1** | + Back Squats    |      3 | 15-18             |
# +----+-------------+------------------+--------+-------------------+
# | 17 | * **Day 1** | + Leg Press      |      2 | 15-18             |
# +----+-------------+------------------+--------+-------------------+
# | 18 | * **Day 1** | + Single Leg Ext |      2 | 15-18  (per leg)  |
# +----+-------------+------------------+--------+-------------------+
# | 19 | * **Day 2** | + Lat Pulldown   |      3 | 15-18             |
# +----+-------------+------------------+--------+-------------------+
# | 20 | * **Day 2** | + Bench Press    |      2 | 15-18             |
# +----+-------------+------------------+--------+-------------------+
# | 21 | * **Day 2** | + Back Ext       |      2 | 15-18  (per side) |
# +----+-------------+------------------+--------+-------------------+
# | 22 | * **Day 3** | + Deadlifts      |      2 | 15-18             |
# +----+-------------+------------------+--------+-------------------+
# | 23 | * **Day 1** | + Back Squats    |      3 | 20-25             |
# +----+-------------+------------------+--------+-------------------+
# | 24 | * **Day 1** | + Leg Press      |      2 | 20-25             |
# +----+-------------+------------------+--------+-------------------+
# | 25 | * **Day 1** | + Single Leg Ext |      2 | 20-25  (per leg)  |
# +----+-------------+------------------+--------+-------------------+
# | 26 | * **Day 2** | + Lat Pulldown   |      3 | 20-25             |
# +----+-------------+------------------+--------+-------------------+
# | 27 | * **Day 2** | + Bench Press    |      2 | 20-25             |
# +----+-------------+------------------+--------+-------------------+
#
#
#
# ========================================
# Training Plan for Tyrone
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Jessi
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Shalaka
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Chantalle
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Cathy
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Sophie Weißgerber
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for J
# ========================================
# +----+------------------------------------+-------------------------+--------+-----------------+
# |    | Day                                | Exercise                |   Sets | Reps            |
# +====+====================================+=========================+========+=================+
# |  0 | **Day 1: Full-Body Workout**       | * Back Squats           |      3 | 10-12           |
# +----+------------------------------------+-------------------------+--------+-----------------+
# |  1 | **Day 1: Full-Body Workout**       | * Leg Press             |      3 | 10-12           |
# +----+------------------------------------+-------------------------+--------+-----------------+
# |  2 | **Day 1: Full-Body Workout**       | * Single Leg Extensions |      3 | 10-12  per leg  |
# +----+------------------------------------+-------------------------+--------+-----------------+
# |  3 | **Day 2: Upper Body Workout**      | * Lat Pulldowns         |      3 | 10-12           |
# +----+------------------------------------+-------------------------+--------+-----------------+
# |  4 | **Day 2: Upper Body Workout**      | * Bench Press           |      3 | 10-12           |
# +----+------------------------------------+-------------------------+--------+-----------------+
# |  5 | **Day 2: Upper Body Workout**      | * Back Extensions       |      3 | 10-12           |
# +----+------------------------------------+-------------------------+--------+-----------------+
# |  6 | **Day 3: Leg Day**                 | * Deadlifts             |      3 | 10-12           |
# +----+------------------------------------+-------------------------+--------+-----------------+
# |  7 | **Day 3: Leg Day**                 | * Leg Press             |      3 | 10-12           |
# +----+------------------------------------+-------------------------+--------+-----------------+
# |  8 | **Day 3: Leg Day**                 | * Hip Abductions        |      2 | 10-12  per leg  |
# +----+------------------------------------+-------------------------+--------+-----------------+
# |  9 | **Day 4: Glutes and Core Workout** | * Glute Bridges         |      3 | 10-12           |
# +----+------------------------------------+-------------------------+--------+-----------------+
# | 10 | **Day 4: Glutes and Core Workout** | * Hip Abductions        |      2 | 10-12  per leg  |
# +----+------------------------------------+-------------------------+--------+-----------------+
# | 11 | **Day 4: Glutes and Core Workout** | * Plank                 |      3 | 30-60 seconds   |
# +----+------------------------------------+-------------------------+--------+-----------------+
# | 12 | **Day 4: Glutes and Core Workout** | * Russian Twists        |      3 | 10-12  per side |
# +----+------------------------------------+-------------------------+--------+-----------------+
#
#
#
# ========================================
# Training Plan for Lorenz Pietsch
# ========================================
# +----+------------------------------+-----------------------------------------------------------------------+--------+------------------+
# |    | Day                          | Exercise                                                              |   Sets | Reps             |
# ...
# +----+------------------------------+-----------------------------------------------------------------------+--------+------------------+
# |  9 | **Day 2 (Upper Body Focus)** | * Tricep Dips (using a chair or bench)                                |      2 | 12-15            |
# +----+------------------------------+-----------------------------------------------------------------------+--------+------------------+
# | 10 | **Day 3 (Core and Glutes)**  | * Deadlifts                                                           |      3 | 8-10             |
# +----+------------------------------+-----------------------------------------------------------------------+--------+------------------+
# | 11 | **Day 3 (Core and Glutes)**  | * Hip Abduction                                                       |      2 | 12-15            |
# +----+------------------------------+-----------------------------------------------------------------------+--------+------------------+
# | 12 | **Day 3 (Core and Glutes)**  | * Russian twists (using a weight or medicine ball)                    |      3 | 15-20            |
# +----+------------------------------+-----------------------------------------------------------------------+--------+------------------+
# | 13 | **Day 3 (Core and Glutes)**  | * Leg Raises (hanging leg raises or lying on back with arms extended) |      3 | 12-15            |
# +----+------------------------------+-----------------------------------------------------------------------+--------+------------------+
# | 14 | **Day 3 (Core and Glutes)**  | * Glute Bridges                                                       |      2 | 10-12            |
# +----+------------------------------+-----------------------------------------------------------------------+--------+------------------+
#
#
#
# ========================================
# Training Plan for Emily
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Tim
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Tester
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Carina Stetca
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for K
# ========================================
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# |    | Day                           | Exercise                                |   Sets | Reps             |
# +====+===============================+=========================================+========+==================+
# |  0 | **Day 1: Chest and Triceps**  | 1. Barbell Bench Press                  |      3 | 10-12            |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# |  1 | **Day 1: Chest and Triceps**  | 2. Incline Dumbbell Press               |      3 | 8-10             |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# |  2 | **Day 1: Chest and Triceps**  | 3. Cable Flyes                          |      3 | 10-12            |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# |  3 | **Day 1: Chest and Triceps**  | 4. Tricep Pushdowns                     |      3 | 9-11             |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# |  4 | **Day 1: Chest and Triceps**  | 5. Tricep Dips (using a bench or chair) |      3 | 10-12            |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# |  5 | **Day 2: Back and Biceps**    | 1. Pull-ups or Lat Pulldowns            |      3 | 8-10             |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# |  6 | **Day 2: Back and Biceps**    | 2. Barbell Rows                         |      3 | 8-10             |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# |  7 | **Day 2: Back and Biceps**    | 3. Seated Cable Rows                    |      3 | 9-11             |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# |  8 | **Day 2: Back and Biceps**    | 4. Dumbbell Bicep Curls                 |      3 | 8-10             |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# |  9 | **Day 2: Back and Biceps**    | 5. Hammer Curls (using dumbbells)       |      3 | 9-11             |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# | 10 | **Day 3: Legs and Shoulders** | 1. Squats                               |      3 | 8-10             |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# | 11 | **Day 3: Legs and Shoulders** | 2. Leg Press                            |      3 | 8-10             |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# | 12 | **Day 3: Legs and Shoulders** | 3. Lunges                               |      3 | 10-12  (per leg) |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# | 13 | **Day 3: Legs and Shoulders** | 4. Standing Military Press              |      3 | 7-9              |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
# | 14 | **Day 3: Legs and Shoulders** | 5. Seated Dumbbell Shoulder Press       |      3 | 6-8              |
# +----+-------------------------------+-----------------------------------------+--------+------------------+
#
#
#
# ========================================
# Training Plan for Udi
# ========================================
# +----+----------------------+----------------------------------+--------+-------------+
# |    | Day                  | Exercise                         |   Sets | Reps        |
# +====+======================+==================================+========+=============+
# |  0 | Monday (Cardio Day): | + Bicep Curls with Light Weights |      3 | 12          |
# +----+----------------------+----------------------------------+--------+-------------+
# |  1 | Monday (Cardio Day): | + Tricep Dips                    |      3 | 12          |
# +----+----------------------+----------------------------------+--------+-------------+
# |  2 | Monday (Cardio Day): | + Shoulder Press                 |      3 | 12          |
# +----+----------------------+----------------------------------+--------+-------------+
# |  3 | Monday (Cardio Day): | + Chest Flys                     |      3 | 12          |
# +----+----------------------+----------------------------------+--------+-------------+
# |  4 | Wednesday (Rest Day) | + Squats with Light Weights      |      3 | 12          |
# +----+----------------------+----------------------------------+--------+-------------+
# |  5 | Wednesday (Rest Day) | + Lunges                         |      3 | 12  per leg |
# +----+----------------------+----------------------------------+--------+-------------+
# |  6 | Wednesday (Rest Day) | + Calf Raises                    |      3 | 12          |
# +----+----------------------+----------------------------------+--------+-------------+
# |  7 | Wednesday (Rest Day) | + Leg Press                      |      3 | 10-12       |
# +----+----------------------+----------------------------------+--------+-------------+
#
#
#
# ========================================
# Training Plan for Monika
# ========================================
# +----+----------+-----------------------------+--------+-------------------+
# |    | Day      | Exercise                    |   Sets | Reps              |
# +====+==========+=============================+========+===================+
# |  0 | * Day 1: | + Squats                    |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# |  1 | * Day 1: | + Leg Press                 |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# |  2 | * Day 1: | + Seated Leg Extensions     |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# |  3 | * Day 1: | + Planks                    |      3 | 30-second hold    |
# +----+----------+-----------------------------+--------+-------------------+
# |  4 | * Day 2: | + Lat Pulldowns             |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# |  5 | * Day 2: | + Seated Row                |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# |  6 | * Day 2: | + Leg Curls                 |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# |  7 | * Day 2: | + Russian Twists            |      3 | 10-12  (per side) |
# +----+----------+-----------------------------+--------+-------------------+
# |  8 | * Day 3: | + Deadlifts                 |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# |  9 | * Day 3: | + Leg Press                 |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# | 10 | * Day 3: | + Hip Abductions            |      2 | 10-12  (per leg)  |
# +----+----------+-----------------------------+--------+-------------------+
# | 11 | * Day 1: | + Bench Press               |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# | 12 | * Day 1: | + Incline Dumbbell Press    |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# | 13 | * Day 1: | + Tricep Pushdowns          |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# | 14 | * Day 1: | + Bicep Curls               |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# | 15 | * Day 2: | + Chest Press               |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# | 16 | * Day 2: | + Seated Cable Rows         |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# | 17 | * Day 2: | + Leg Curls                 |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# | 18 | * Day 2: | + Reverse Flys              |      3 | 10-12  (per side) |
# +----+----------+-----------------------------+--------+-------------------+
# | 19 | * Day 3: | + Pull-ups or Lat Pulldowns |      3 | 8-10              |
# +----+----------+-----------------------------+--------+-------------------+
# | 20 | * Day 3: | + Seated Leg Extensions     |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# | 21 | * Day 3: | + Russian Twists            |      3 | 10-12  (per side) |
# +----+----------+-----------------------------+--------+-------------------+
# | 22 | * Day 1: | + Deadlifts                 |      3 | 8-10              |
# +----+----------+-----------------------------+--------+-------------------+
# | 23 | * Day 1: | + Leg Press                 |      3 | 8-10              |
# +----+----------+-----------------------------+--------+-------------------+
# | 24 | * Day 1: | + Glute Bridges             |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# | 25 | * Day 1: | + Calf Raises               |      3 | 10-12             |
# +----+----------+-----------------------------+--------+-------------------+
# | 26 | * Day 2: | + Bench Press               |      3 | 8-10              |
# +----+----------+-----------------------------+--------+-------------------+
# | 27 | * Day 2: | + Incline Dumbbell Press    |      3 | 8-10              |
# +----+----------+-----------------------------+--------+-------------------+
# | 28 | * Day 2: | + Tricep Pushdowns          |      3 | 8-10              |
# +----+----------+-----------------------------+--------+-------------------+
# | 29 | * Day 2: | + Bicep Curls               |      3 | 8-10              |
# +----+----------+-----------------------------+--------+-------------------+
# | 30 | * Day 3: | + Pull-ups or Lat Pulldowns |      3 | 6-8               |
# +----+----------+-----------------------------+--------+-------------------+
# | 31 | * Day 3: | + Seated Cable Rows         |      3 | 8-10              |
# +----+----------+-----------------------------+--------+-------------------+
# | 32 | * Day 3: | + Leg Curls                 |      3 | 8-10              |
# +----+----------+-----------------------------+--------+-------------------+
# | 33 | * Day 1: | + Deadlifts                 |      3 | 6-8               |
# +----+----------+-----------------------------+--------+-------------------+
# | 34 | * Day 1: | + Leg Press                 |      3 | 6-8               |
# +----+----------+-----------------------------+--------+-------------------+
# | 35 | * Day 1: | + Hip Abductions            |      2 | 10-12  (per leg)  |
# +----+----------+-----------------------------+--------+-------------------+
# | 36 | * Day 2: | + Bench Press               |      3 | 6-8               |
# +----+----------+-----------------------------+--------+-------------------+
# | 37 | * Day 2: | + Incline Dumbbell Press    |      3 | 6-8               |
# +----+----------+-----------------------------+--------+-------------------+
# | 38 | * Day 2: | + Tricep Pushdowns          |      3 | 6-8               |
# +----+----------+-----------------------------+--------+-------------------+
# | 39 | * Day 2: | + Bicep Curls               |      3 | 6-8               |
# +----+----------+-----------------------------+--------+-------------------+
# | 40 | * Day 3: | + Pull-ups or Lat Pulldowns |      3 | 4-6               |
# +----+----------+-----------------------------+--------+-------------------+
# | 41 | * Day 3: | + Seated Cable Rows         |      3 | 8-10              |
# +----+----------+-----------------------------+--------+-------------------+
# | 42 | * Day 3: | + Leg Curls                 |      3 | 6-8               |
# +----+----------+-----------------------------+--------+-------------------+
#
#
#
# ========================================
# Training Plan for Shayan
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+
#
#
#
# ========================================
# Training Plan for Agnes
# ========================================
# +-------+------------+--------+--------+
# | Day   | Exercise   | Sets   | Reps   |
# +=======+============+========+========+
# +-------+------------+--------+--------+

# %%
import pandas as pd
from tabulate import tabulate

# Load the CSV file
file_path = "user_training_plans.csv"
training_data = pd.read_csv(file_path)

# Select only relevant columns (e.g., Name and Training_Plan)
relevant_data = training_data[["Name ", "Training_Plan"]]

# Display each user's training plan in a structured format
for _, row in relevant_data.iterrows():
    name = row["Name "]
    training_plan = row["Training_Plan"]
    
    print(f"\n{'='*40}\nTraining Plan for {name}\n{'='*40}")
    
    # Split the training plan into lines for better readability
    plan_lines = training_plan.split("\n")
    for line in plan_lines:
        print(line)
# Out:
# ========================================
# Training Plan for A
# ========================================
# Based on the provided information, I'll create a personalized training plan for the user.
#
# **Training Goals:**
#
# * Building muscle strength
# * Achieving overall balance and strength
# * Focusing on arms (biceps, triceps, forearms)
# * Focusing on legs (quadriceps, hamstrings, calves)
# * Focusing on glutes (buttocks)
#
# **Workout Frequency:** 2 days per week
#
# **Rest Periods:**
#
# * Day 1: 60 minutes
# * Day 3: 60 minutes
#
# **Equipment:**
#
# * None mentioned (user has gym access at home)
#
# **Sample Training Plan:**
#
# **Day 1: Chest and Triceps**
#
# 1. Warm-up: 5-minute dynamic stretching (arm circles, leg swings)
# 2. Barbell Bench Press: 3 sets of 10-12 reps
# 	* Lie on a flat bench and grip the bar with your hands shoulder-width apart
# 	* Lower the bar to your chest, then press upwards until your arms are fully extended
# 3. Incline Dumbbell Press: 3 sets of 10-12 reps (per arm)
# 	* Sit on an incline bench and hold a dumbbell in each hand
# 	* Press the dumbbells upwards towards the ceiling, then lower them back down to the starting position
# 4. Tricep Pushdowns: 3 sets of 10-12 reps (per arm)
# 	* Hold a barbell or rope attachment with your hands shoulder-width apart
# 	* Extend your arms fully downwards, then return to the starting position
# 5. Overhead Dumbbell Extension: 3 sets of 10-12 reps
# 	* Stand with your feet shoulder-width apart and hold a dumbbell in each hand overhead with your arms extended
# 	* Lower the dumbbells behind your head, then raise them back up to the starting position
#
# **Day 2: Back and Biceps**
#
# 1. Warm-up: 5-minute dynamic stretching (arm circles, leg swings)
# 2. Deadlifts: 3 sets of 10-12 reps
# 	* Stand with your feet shoulder-width apart and hold a barbell or dumbbells with your hands shoulder-width apart
# 	* Keeping your back straight and core engaged, lift the weight off the ground and stand up straight
# 3. Bent-Over Barbell Rows: 3 sets of 10-12 reps (per arm)
# 	* Hold a barbell or dumbbells with your hands shoulder-width apart and bend over at the waist
# 	* Let your arms hang straight down from your shoulders, then lift the weight up to your chest and lower it back down to the starting position
# 4. Dumbbell Bicep Curls: 3 sets of 10-12 reps (per arm)
# 	* Stand with your feet shoulder-width apart and hold a dumbbell in each hand with your palms facing forward
# 	* Curl the dumbbells up towards your shoulders, then lower them back down to the starting position
# 5. Hammer Curls: 3 sets of 10-12 reps (per arm)
# 	* Stand with your feet shoulder-width apart and hold a dumbbell in each hand with your palms facing towards your body
# 	* Curl the dumbbells up towards your shoulders, then lower them back down to the starting position
#
# **Day 3: Legs**
#
# 1. Warm-up: 5-minute dynamic stretching (leg swings, lunges)
# 2. Leg Press: 3 sets of 10-12 reps
# 	* Sit in a leg press machine with your feet shoulder-width apart on the platform
# 	* Push the platform away from you, extending your legs fully, then lower it back down to the starting position
# 3. Romanian Deadlifts: 3 sets of 10-12 reps (per leg)
# 	* Stand with your feet shoulder-width apart and hold a barbell or dumbbells with your hands shoulder-width apart
# 	* Keeping your back straight and core engaged, lift the weight off the ground and stand up straight
# 4. Leg Extensions: 3 sets of 10-12 reps (per leg)
# 	* Sit in a leg extension machine with your legs extended out in front of you
# 	* Lift the weight up towards your legs, then lower it back down to the starting position
#
# **Day 4: Cardio and Rest**
#
# 1. Warm-up: 5-minute dynamic stretching (arm circles, leg swings)
# 2. High-Intensity Interval Training (HIIT): 20 minutes (e.g., sprints, burpees, jump squats)
# 3. Cool-down: 5-minute static stretching (focusing on major muscle groups)
#
# **Progressive Overload:**
#
# * Increase the weight by 2.5-5kg every two weeks, or as soon as you feel you can lift more.
# * Decrease rest periods by 1-2 minutes every week.
#
# **Additional Tips:**
#
# * Eat a balanced diet that includes protein-rich foods, complex carbohydrates, and healthy fats to support muscle growth and recovery.
# * Get at least 7-8 hours of sleep per night to aid in muscle recovery and growth.
# * Stay hydrated throughout the day by drinking plenty of water.
#
# ========================================
# Training Plan for B
# ========================================
# Based on the provided user data, I've created a personalized training plan for them. Please note that this is just an example, and it's always best to consult with a healthcare professional or certified trainer before starting any new exercise program.
#
# **Training Plan:**
#
# **Goal:** Build muscle strength in the legs (quadriceps, hamstrings, calves) and back (upper and lower back), while maintaining flexibility and mobility.
#
# **User Data:**
#
# * Name: B
# * Age: 35
# * Gender: Male
# * Height (cm): 182.0
# * Weight (Kg): 85
# * Fitness Level: Beginner
# * Workout Frequency: 3 days per week
# * Workout Duration: 60 minutes per session
# * Home Office setup
# * No injury or medical condition
# * Daily activity: Home Office
#
# **Day 1: Legs and Back**
#
# | Exercise | Sets | Reps |
# | --- | --- | --- |
# | Squats | 3 | 10-12 |
# | Leg Press | 3 | 10-12 |
# | Single-Leg Extension | 3 | 10-12 |
# | Lat Pulldown | 3 | 10-12 |
# | Bench Press | 3 | 10-12 |
# | Back Extensions | 3 | 10-12 |
#
# **Day 2: Cardio and Active Recovery**
#
# * Choose a low-intensity cardio activity, such as:
# 	+ Brisk walking (30 minutes)
# 	+ Swimming or cycling (20 minutes)
# 	+ Light jogging or running (20 minutes)
#
# **Day 3: Legs and Back**
#
# | Exercise | Sets | Reps |
# | --- | --- | --- |
# | Deadlifts | 3 | 10-12 |
# | Leg Press | 3 | 10-12 |
# | Hip Abduction | 2 | 10-12 |
#
# **Progressive Overload and Variation:**
#
# * Increase weight or reps by 0.5-1 kg every two weeks, as the user's strength and fitness level adapt to the program.
# * Add isolation exercises (e.g., bicep curls, tricep extensions) once a week to target specific muscle groups.
#
# **Additional Tips:**
#
# * Start with lighter weights and progress gradually.
# * Focus on proper form and technique throughout each exercise.
# * Rest for 60-90 seconds between sets and 120-180 seconds between exercises.
# * Incorporate stretching exercises after workouts to improve flexibility and range of motion.
#
# By following this personalized training plan, B can expect to see improvement in their strength and muscle mass over time. Remember to stay consistent, patient, and listen to their body's needs to achieve optimal results.
#
# ========================================
# Training Plan for C
# ========================================
# Based on the provided information, I've created a personalized training plan for the user. Here it is:
#
# **Example Training Plan:**
#
# **User:** C
# **Age:** 34
# **Gender:** Female
# **Height (cm):** 162.0
# **Weight (Kg):** 76
# **Fitness Goals:**
# 1. Building muscle strength
# 2. Stress relief and mental well-being
# 3. Increasing energy levels
#
# **Workout Schedule:**
#
# The user plans to work out 3 days per week, with a dedicated day for each workout session.
#
# * **Day 1:** Full Body Workout (60 minutes)
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Exercises:
# 		- Squats: 3 sets of 10-12 reps
# 		- Leg Press: 3 sets of 10-12 reps
# 		- Single-Leg Extensions: 3 sets of 10-12 reps (per leg)
# 		- Core exercises: Plank, Russian twists, and leg raises
# * **Day 2:** Hip and Lower Back Workout (60 minutes)
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Exercises:
# 		- Lat Pulldowns: 3 sets of 10-12 reps
# 		- Bench Press: 3 sets of 10-12 reps
# 		- Back Extensions: 3 sets of 10-12 reps
# 		- Glute bridges and hip flexor exercises (optional)
# * **Day 3:** Cardio Day with Hip Abduction Exercises (60 minutes)
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Exercise:
# 		- Burpees: 2 sets of 10-12 reps ( Hip abduction exercises included)
#
# **Additional Tips and Considerations:**
#
# 1. Rest periods should be longer during strength phases to allow for recovery.
# 2. Cardio sessions can be shorter, but still aim for at least 30 minutes per session.
# 3. Warm up and cool down with dynamic stretching before each workout.
# 4. Adjust the intensity and volume of workouts based on user's feedback and progress.
#
# **Progressive Overload:**
#
# To avoid plateaus, make small increases in weight or reps every two weeks:
#
# * Week 2-4: Increase weight by 2.5kg/5lbs
# * Week 6-8: Decrease rest time to 60-90 seconds
#
# **Accessory Exercises and Variation:**
#
# Incorporate hip abduction exercises during strength-focused phases, such as Deadlifts or Hip Abduction.
#
# Consider adding cardio sessions once a week, focusing on lower-intensity activities like cycling, jogging, or rowing.
#
# ========================================
# Training Plan for D
# ========================================
# Based on the provided information, I'll create a personalized training plan for the user.
#
# **User Details:**
#
# * Name: D
# * Age: 33
# * Gender: Female
# * Height (cm): 160.0
# * Weight (Kg): 63
#
# **Fitness Goals:**
#
# * Weight Loss
# * Building muscle strength
#
# **Workout Frequency:** 3 days per week, with 30-60 minutes per session
#
# **Dedicated Time:** None mentioned; will dedicate as much time as possible to workouts.
#
# **Available Equipment at Home:**
#
# * Nan (no specific equipment mentioned)
#
# **Specific Areas of Focus:**
#
# * Core (abs, obliques, lower back)
# * Arms (biceps, triceps, forearms)
# * Legs (quadriceps, hamstrings, calves)
# * Back (upper and lower back)
# * Posture and alignment
#
# **Injury or Medical Condition:** Yes (Wrist)
#
# **Daily Activity:**
#
# * Home Office (e.g., remote work or studying from home)
#
# Given the user's goals and preferences, I'll create a 3-day workout plan, with varying exercises to target different muscle groups. Please note that this is just an example plan and may need to be adjusted based on individual progress and health.
#
# **Day 1: Chest and Triceps**
#
# 1. Warm-up (5 minutes):
# 	* Jumping jacks
# 	* Dynamic stretching for chest and triceps
# 2. Exercises:
# 	* Barbell Bench Press (3 sets of 10-12 reps)
# 	* Incline Dumbbell Press (3 sets of 10-12 reps per arm)
# 	* Cable Flyes (3 sets of 12 reps per arm)
# 	* Tricep Pushdowns (3 sets of 10-12 reps)
# 	* Overhead Dumbbell Extension (3 sets of 12 reps)
# 3. Cool-down (5 minutes):
# 	* Static stretching for chest and triceps
#
# **Day 2: Back and Biceps**
#
# 1. Warm-up (5 minutes):
# 	* Jumping jacks
# 	* Dynamic stretching for back and biceps
# 2. Exercises:
# 	* Deadlifts (3 sets of 10-12 reps)
# 	* Bent-Over Barbell Rows (3 sets of 10-12 reps per arm)
# 	* Lat Pulldowns (3 sets of 10-12 reps)
# 	* Dumbbell Bicep Curls (3 sets of 10-12 reps per arm)
# 	* Hammer Curls (3 sets of 10-12 reps per arm)
# 3. Cool-down (5 minutes):
# 	* Static stretching for back and biceps
#
# **Day 3: Legs and Shoulders**
#
# 1. Warm-up (5 minutes):
# 	* Jumping jacks
# 	* Dynamic stretching for legs and shoulders
# 2. Exercises:
# 	* Squats (3 sets of 10-12 reps)
# 	* Leg Press (3 sets of 10-12 reps)
# 	* Standing Military Press (3 sets of 8-10 reps per arm)
# 	* Lateral Raises (3 sets of 10-12 reps per arm)
# 	* Rear Delt Flyes (3 sets of 12 reps per arm)
# 3. Cool-down (5 minutes):
# 	* Static stretching for legs and shoulders
#
# **Additional Tips:**
#
# * Incorporate cardio exercises like jogging, cycling, or swimming for at least 30 minutes, 2-3 times a week.
# * Aim to increase the weight or reps every two weeks to challenge the muscles further.
# * Adjust the plan based on individual progress and health.
#
# This personalized training plan should provide a good starting point for D. Encourage her to focus on progressive overload, proper form, and consistency throughout the program.
#
# ========================================
# Training Plan for E
# ========================================
# Based on the provided information, I'll create a personalized training plan for the user.
#
# **Assumptions:**
#
# * The user has a homemaker occupation (e.g., managing household responsibilities full-time) with an average daily activity level of moderate to high intensity.
# * The user has one specific area of the body they want to focus on: Full-body balance and strength, particularly focusing on their back.
# * The user is new to working out and needs guidance on creating a balanced training program.
#
# **Training Plan Structure:**
#
# The plan will be structured into 4 phases:
#
# Phase 1: Building Foundation (Weeks 1-8)
#
# * Focus on building overall muscle mass, flexibility, and strength
# * Include exercises that target the back muscles
#
# Phase 2: Hypertrophy (Weeks 9-16)
#
# * Increase the intensity of workouts by adding more sets, reps, or weight
# * Emphasize exercises that target specific muscle groups to build muscle endurance
#
# Phase 3: Strength Progression (Weeks 17-24)
#
# * Gradually increase the weight or resistance used in workouts
# * Focus on building strength and muscle mass, particularly in the back muscles
#
# Phase 4: Refining Technique and Maintenance (Weeks 25-32)
#
# * Continue to challenge the user with progressive overload exercises
# * Emphasize proper form and technique to prevent injury and ensure long-term progress
#
# **Sample Training Plan:**
#
# Here's a sample training plan tailored to the user's needs:
#
# **Day 1:** Back Squats (3 sets of 10-12 reps)
#
# * Warm-up: 5-minute cardio (jogging, jumping jacks)
# * Back Squats: 3 sets of 10-12 reps
# * Cool-down: 5-minute stretching
#
# **Day 2:** Lat Pulldown and Bench Press (3 sets each of 10-12 reps)
#
# * Warm-up: 5-minute cardio (jogging, jumping jacks)
# * Lat Pulldown: 3 sets of 10-12 reps
# * Bench Press: 3 sets of 10-12 reps
# * Cool-down: 5-minute stretching
#
# **Day 3:** Deadlifts and Hip Abduction (2 sets each of 10-12 reps)
#
# * Warm-up: 5-minute cardio (jogging, jumping jacks)
# * Deadlifts: 2 sets of 10-12 reps
# * Hip Abduction: 2 sets of 10-12 reps
# * Cool-down: 5-minute stretching
#
# **Day 4:** Rest Day**
#
# **Phase 1 (Weeks 1-8):**
#
# * Warm-up: 5-minute cardio (jogging, jumping jacks)
# * Back Squats: 3 sets of 10-12 reps
# * Lat Pulldown and Bench Press: 3 sets each of 10-12 reps
# * Deadlifts: 2 sets of 10-12 reps
# * Hip Abduction: 2 sets of 10-12 reps
#
# **Phase 2 (Weeks 9-16):**
#
# * Warm-up: 5-minute cardio (jogging, jumping jacks)
# * Back Squats: 3 sets of 12-15 reps
# * Lat Pulldown and Bench Press: 3 sets each of 12-15 reps
# * Deadlifts: 2 sets of 12-15 reps
# * Hip Abduction: 2 sets of 12-15 reps
#
# **Phase 3 (Weeks 17-24):**
#
# * Warm-up: 5-minute cardio (jogging, jumping jacks)
# * Back Squats: 3 sets of 15-18 reps
# * Lat Pulldown and Bench Press: 3 sets each of 15-18 reps
# * Deadlifts: 2 sets of 15-18 reps
# * Hip Abduction: 2 sets of 15-18 reps
#
# **Phase 4 (Weeks 25-32):**
#
# * Warm-up: 5-minute cardio (jogging, jumping jacks)
# * Back Squats: 3 sets of 18-20 reps
# * Lat Pulldown and Bench Press: 3 sets each of 18-20 reps
# * Deadlifts: 2 sets of 18-20 reps
# * Hip Abduction: 2 sets of 18-20 reps
#
# **Progressive Overload:**
#
# * Increase the weight or resistance used in workouts by 2.5kg/5lbs every two weeks.
#
# **Monitoring Progress:**
#
# * Track user's weight, body fat percentage, and measurements (e.g., chest, back, waist) weekly.
# * Take progress photos every four weeks to track visual changes.
#
# This training plan will help the user build overall muscle mass, strength, and balance in their back muscles. Remember to adjust the intensity and volume of workouts according to the user's comfort level and any concerns they may have.
#
# ========================================
# Training Plan for G
# ========================================
# Based on the user's information, I'll create a personalized training plan for them. Here it is:
#
# **Training Plan:**
#
# **Weeks 1-4: Foundation Building (Beginner)**
#
# * **Day 1**
# 	+ Back Squats: 3 sets of 10-12 reps
# 	+ Leg Press: 3 sets of 10-12 reps
# 	+ Single-Leg Deadlifts: 2 sets of 10-12 reps per leg
# * **Day 2**
# 	+ Lat Pulldown: 3 sets of 10-12 reps
# 	+ Bench Press: 3 sets of 10-12 reps
# 	+ Back Extensions (seated row): 3 sets of 10-12 reps
# * **Day 3**
# 	+ Rest day
# * **Day 4**
# 	+ Deadlifts: 3 sets of 10-12 reps
# 	+ Leg Press: 3 sets of 10-12 reps
# 	+ Hip Abductions (seated leg press): 2 sets of 10-12 reps per leg
#
# **Weeks 5-8: Hypertrophy and Strength Progression**
#
# * **Day 1**
# 	+ Back Squats: 4 sets of 8-10 reps
# 	+ Leg Press: 3 sets of 9-11 reps
# 	+ Single-Leg Deadlifts: 2 sets of 8-10 reps per leg
# * **Day 2**
# 	+ Lat Pulldown: 4 sets of 8-10 reps
# 	+ Bench Press: 4 sets of 8-10 reps
# 	+ Back Extensions (seated row): 3 sets of 8-10 reps
# * **Day 3**
# 	+ Rest day
# * **Day 4**
# 	+ Deadlifts: 4 sets of 8-10 reps
# 	+ Leg Press: 3 sets of 9-11 reps
# 	+ Hip Abductions (seated leg press): 2 sets of 8-10 reps per leg
#
# **Weeks 9-12: Strength and Endurance**
#
# * **Day 1**
# 	+ Back Squats: 5 sets of 6-8 reps
# 	+ Leg Press: 4 sets of 7-9 reps
# 	+ Single-Leg Deadlifts: 3 sets of 6-8 reps per leg
# * **Day 2**
# 	+ Lat Pulldown: 5 sets of 6-8 reps
# 	+ Bench Press: 5 sets of 6-8 reps
# 	+ Back Extensions (seated row): 4 sets of 6-8 reps
# * **Day 3**
# 	+ Rest day
# * **Day 4**
# 	+ Deadlifts: 5 sets of 6-8 reps
# 	+ Leg Press: 4 sets of 7-9 reps
# 	+ Hip Abductions (seated leg press): 2 sets of 6-8 reps per leg
#
# **Cardio**
#
# * **Monday, Wednesday, Friday**: 20-minute steady-state cardio session (jogging, cycling, or rowing)
# * **Tuesday, Thursday**: 10-minute high-intensity interval training (HIIT) session (burpees, jump squats, etc.)
#
# **Rest and Recovery**
#
# * Aim for 1-2 rest days per week
# * Stretch after each workout and take a day off every 3-4 weeks
#
# **Note:**
#
# * Warm up before each workout with 5-10 minutes of light cardio and dynamic stretching.
# * Adjust the weights and reps according to your fitness level and goals.
# * Increase the weight or reps as you get stronger, but avoid sacrificing form for heavier weights.
# * Focus on proper nutrition and adequate sleep to support muscle growth and recovery.
#
# **User's Progress:**
#
# * Weight gain: 2-3 kg (4-6 lbs) in Weeks 1-4
# * Bench Press: 120 kg (264 lbs)
# * Squats: 150 kg (330 lbs)
# * Deadlifts: 170 kg (375 lbs)
#
# **Injury and Medical Condition:**
#
# The user has knee pain, which may require modifications to the workout plan. They should consult with a doctor or physical therapist before starting any new exercise program.
#
# This personalized training plan is designed to help the user build strength, hypertrophy, and endurance while addressing their specific injury concerns. Remember to listen to your body and adjust the plan as needed to ensure safe and effective progress!
#
# ========================================
# Training Plan for Sohini
# ========================================
# Based on the provided information, I'll create a personalized training plan for Sohini.
#
# **Training Plan:**
#
# **Goals:**
#
# * Weight Loss
# * Enhancing flexibility and mobility
# * Stress relief and mental well-being
# * Increasing energy levels
# * Toning and sculpting the body (Core)
#
# **User Data:**
#
# * Age: 26
# * Height: 162.0 cm
# * Weight: 69 kg
#
# **Workout Frequency:** 4 days per week
#
# **Workout Duration:** 60 minutes per session
#
# **Equipment Available:** None, so I'll provide a simple home workout plan using bodyweight exercises.
#
# **Monday (Upper Body and Core):**
#
# 1. Warm-up: 5-minute dynamic stretching
# 2. Push-ups: 3 sets of 10-12 reps
# 	* Rest for 30 seconds between sets
# 3. Dumbbell Chest Press: 3 sets of 10-12 reps
# 	* Hold dumbbells in each hand and press upwards, extending arms fully
# 4. Inverted Rows (using a chair or bench): 3 sets of 10-12 reps
# 	* Hold the bar with hands shoulder-width apart and pull towards chest
# 5. Plank: 3 sets, holding for 30 seconds to engage core muscles
# 6. Russian twists (sitting on floor with knees bent and feet flat): 3 sets of 10-12 reps
# 	* Hold a weight or medicine ball in front of chest and twist torso from side to side
# 7. Cool-down: 5-minute static stretching
#
# **Wednesday (Lower Body and Glutes):**
#
# 1. Warm-up: 5-minute dynamic stretching
# 2. Squats: 3 sets of 10-12 reps
# 	* Hold body weight with feet shoulder-width apart, then lower down slowly
# 3. Calf raises: 3 sets of 15-20 reps
# 	* Stand on edge of step or curb with heels hanging off, raise up onto tiptoes and lower back down
# 4. Glute bridges: 3 sets of 10-12 reps
# 	* Lie on back with knees bent and feet flat, lift hips up towards ceiling
# 5. Step-ups (using a sturdy chair or bench): 3 sets of 10-12 reps per leg
# 	* Stand in front of chair or bench with right foot forward, step up onto it and bring other foot to meet first one
# 6. Cool-down: 5-minute static stretching
#
# **Friday (Core and Upper Body):**
#
# 1. Warm-up: 5-minute dynamic stretching
# 2. Bicycle crunches: 3 sets of 10-12 reps
# 	* Lie on back with hands behind head, alternate bringing elbow to opposite knee
# 3. Leg raises (hanging leg raises or using a Swiss ball): 3 sets of 15-20 reps
# 	* Lie on back with arms extended overhead and legs straight, lift one leg up towards ceiling
# 4. Tricep dips (using a chair or bench): 3 sets of 10-12 reps per arm
# 	* Sit on edge of chair with hands gripping the edge and lower down slowly
# 5. Shoulder press (using dumbbells or a resistance band): 3 sets of 10-12 reps
# 	* Hold dumbbells in each hand at shoulder height, press upwards and extend arms fully
# 6. Cool-down: 5-minute static stretching
#
# **Progressive Overload:**
#
# * Increase weight or reps by 2.5-5kg/5lbs every two weeks, or as soon as you feel you can handle more.
#
# **Rest Periods:**
#
# * Rest for 30-60 seconds between sets
# * Rest for 1-2 minutes between exercises
#
# **Cardio:**
#
# * Since Sohini has a wrist issue, I'll recommend low-impact cardio options like:
# 	+ Brisk walking or jogging in place
# 	+ Swimming or cycling (use resistance band to modify the motion if needed)
# 	+ Dancing or following a low-impact workout video
#
# **Additional Tips:**
#
# * Listen to your body and rest when needed.
# * Stay hydrated throughout the day.
# * Consider incorporating stretching exercises into daily activities, such as yoga or Pilates.
#
# Here's an example of what her training plan might look like:
#
# | Day | Exercise | Sets Reps |
# | --- | --- | --- |
# | Mon | Push-ups | 3 sets (10-12 reps) |
# | Tue | Dumbbell Chest Press | 3 sets (10-12 reps) |
# | Wed | Squats | 3 sets (10-12 reps) |
# | Thu | Glute bridges | 3 sets (10-12 reps) |
# | Fri | Bicycle crunches | 3 sets (10-12 reps) |
#
# Please note that this is just a sample plan and may need to be adjusted based on individual needs and progress. It's always recommended to consult with a healthcare professional or certified personal trainer before starting any new exercise program.
#
# ========================================
# Training Plan for Kartikey
# ========================================
# Based on the user's input, I'll create a personalized training plan for them. Here it is:
#
# **Training Plan:**
#
# I've created a 4-phase training program that addresses the user's goals of weight loss, building muscle strength, enhancing flexibility and mobility, stress relief, and mental well-being.
#
# **Phase 1: Foundation Building (Weeks 1-4)**
#
# * Day 1:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Squats: 3 sets of 10-12 reps
# 	+ Leg Press: 3 sets of 10-12 reps
# 	+ Lunges: 2 sets of 10-12 reps (per leg)
# 	+ Cool-down: 5-minute static stretching
# * Day 2:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Lat Pulldowns: 3 sets of 10-12 reps
# 	+ Bench Press: 3 sets of 10-12 reps
# 	+ Seated Row: 2 sets of 10-12 reps
# 	+ Cool-down: 5-minute static stretching
# * Day 3:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Deadlifts: 3 sets of 10-12 reps
# 	+ Leg Press: 3 sets of 10-12 reps
# 	+ Hip Abduction: 2 sets of 10-12 reps
# 	+ Cool-down: 5-minute static stretching
#
# **Phase 2: Hypertrophy and Strength (Weeks 5-8)**
#
# * Day 1:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Squats: 3 sets of 8-10 reps
# 	+ Leg Press: 3 sets of 8-10 reps
# 	+ Lunges: 2 sets of 8-10 reps (per leg)
# 	+ Cool-down: 5-minute static stretching
# * Day 2:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Lat Pulldowns: 3 sets of 8-10 reps
# 	+ Bench Press: 3 sets of 8-10 reps
# 	+ Seated Row: 2 sets of 8-10 reps
# 	+ Cool-down: 5-minute static stretching
# * Day 3:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Deadlifts: 3 sets of 8-10 reps
# 	+ Leg Press: 3 sets of 8-10 reps
# 	+ Hip Abduction: 2 sets of 8-10 reps
# 	+ Cool-down: 5-minute static stretching
#
# **Phase 3: Increased Intensity (Weeks 9-12)**
#
# * Day 1:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Squats: 4 sets of 6-8 reps
# 	+ Leg Press: 4 sets of 6-8 reps
# 	+ Lunges: 3 sets of 6-8 reps (per leg)
# 	+ Cool-down: 5-minute static stretching
# * Day 2:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Lat Pulldowns: 4 sets of 6-8 reps
# 	+ Bench Press: 4 sets of 6-8 reps
# 	+ Seated Row: 3 sets of 6-8 reps
# 	+ Cool-down: 5-minute static stretching
# * Day 3:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Deadlifts: 4 sets of 6-8 reps
# 	+ Leg Press: 4 sets of 6-8 reps
# 	+ Hip Abduction: 3 sets of 6-8 reps
# 	+ Cool-down: 5-minute static stretching
#
# **Phase 4: Maximal Endurance (Weeks 13-16)**
#
# * Day 1:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Squats: 5 sets of 4-6 reps
# 	+ Leg Press: 5 sets of 4-6 reps
# 	+ Lunges: 3 sets of 4-6 reps (per leg)
# 	+ Cool-down: 5-minute static stretching
# * Day 2:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Lat Pulldowns: 5 sets of 4-6 reps
# 	+ Bench Press: 5 sets of 4-6 reps
# 	+ Seated Row: 3 sets of 4-6 reps
# 	+ Cool-down: 5-minute static stretching
# * Day 3:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Deadlifts: 5 sets of 4-6 reps
# 	+ Leg Press: 5 sets of 4-6 reps
# 	+ Hip Abduction: 3 sets of 4-6 reps
# 	+ Cool-down: 5-minute static stretching
#
# **Additional Tips and Reminders**
#
# * Warm up with 5-minute dynamic stretching before each workout.
# * Rest for 60-90 seconds between sets, and 120-180 seconds between exercises.
# * Adjust the weights and reps based on your progress and fitness level.
# * Increase the weight or reps as you get stronger.
# * Focus on proper form and technique throughout each exercise.
#
# **Progressive Overload**
#
# To continue making gains in strength and muscle mass, aim to increase the weight by 2.5-5kg every two weeks. This can be achieved by:
#
# * Increasing the number of sets
# * Increasing the number of reps
# * Decreasing rest time between exercises
#
# Remember to also incorporate other forms of exercise, such as cardio and flexibility training, into your routine to support overall fitness and well-being.
#
# I hope this plan helps you achieve your fitness goals!
#
# ========================================
# Training Plan for Shivaksh Sharma
# ========================================
# Based on the user's input, I will create a personalized training plan for Shivaksh Sharma.
#
# **Personalized Training Plan for Shivaksh Sharma**
#
# **Goal:** Building muscle strength and improving overall health and well-being
#
# **Fitness Level:** Intermediate
#
# **Workout Frequency:** 3 days per week (Monday, Wednesday, Friday)
#
# **Duration of Each Workout Session:** 45 minutes
#
# **Equipment Available:**
#
# * Home gym equipment
# * None mentioned previously
#
# **Daily Activity:**
# Shivaksh works as an office job in a sedentary environment.
#
# **Injury/Medical Condition:**
# Minor left lower back pain due to disc bulge
#
# **Current Fitness Level Assessment:**
#
# * Shivaksh is intermediate, meaning he has some experience with working out and knows his limits.
# * His current fitness level is above average but still needs to work on building strength and endurance.
#
# **Training Plan Structure:**
#
# The plan will be divided into three phases:
#
# Phase 1 (Weeks 1-4): Building Foundation Strength
#
# * Monday:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Back Squats: 3 sets of 10-12 reps, 45-second rest between sets
# 	+ Leg Press: 3 sets of 10-12 reps, 45-second rest between sets
# 	+ Single Leg Extensions: 3 sets of 10-12 reps per leg, 45-second rest between sets
# * Wednesday:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Deadlifts: 3 sets of 10-12 reps, 45-second rest between sets
# 	+ Hip Abductions: 2 sets of 10-12 reps per side, 45-second rest between sets
#
# Phase 2 (Weeks 5-8): Building Strength and Endurance
#
# * Monday:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Back Squats: 3 sets of 10-12 reps, 45-second rest between sets
# 	+ Leg Press: 3 sets of 10-12 reps, 45-second rest between sets
# 	+ Single Leg Extensions: 3 sets of 10-12 reps per leg, 45-second rest between sets
# * Wednesday:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Deadlifts: 3 sets of 10-12 reps, 45-second rest between sets
# 	+ Hip Abductions: 2 sets of 10-12 reps per side, 45-second rest between sets
# * Friday:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Back Squats: 3 sets of 10-12 reps, 45-second rest between sets
# 	+ Leg Press: 3 sets of 10-12 reps, 45-second rest between sets
#
# Phase 3 (Weeks 9-12): Building Endurance and Power
#
# * Monday:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Back Squats: 3 sets of 8-10 reps, 30-second rest between sets
# 	+ Leg Press: 3 sets of 8-10 reps, 30-second rest between sets
# 	+ Single Leg Extensions: 3 sets of 8-10 reps per leg, 30-second rest between sets
# * Wednesday:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Deadlifts: 3 sets of 8-10 reps, 30-second rest between sets
# 	+ Hip Abductions: 2 sets of 8-10 reps per side, 30-second rest between sets
# * Friday:
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Back Squats: 3 sets of 8-10 reps, 30-second rest between sets
# 	+ Leg Press: 3 sets of 8-10 reps, 30-second rest between sets
#
# **Progressive Overload:**
#
# * Increase weight or reps by 2.5kg/5lbs each week for the first two weeks.
# * Decrease weight or reps by 1.25kg/2.5lbs each week after that.
#
# **Rest Periods:**
#
# * Phase 1: 60-90 seconds between sets
# * Phase 2 and 3: 45-60 seconds between sets
#
# **Cardiovascular Training (Optional):**
#
# Shivaksh can include cardio exercises 1-2 times per week, such as:
#
# * Jogging or cycling for 20-30 minutes, 1-2 times per week
# * High-intensity interval training (HIIT) for 15-20 minutes, 1 time per week
#
# **Nutrition and Lifestyle:**
#
# Shivaksh will need to focus on a balanced diet with adequate protein intake (1.2-1.6 grams per kilogram of body weight) and carbohydrates. He should also aim to stay hydrated throughout the day.
#
# I hope this personalized training plan meets Shivaksh's fitness goals and helps him achieve overall health and well-being!
#
# ========================================
# Training Plan for Justyna
# ========================================
# Based on the provided information, here is a personalized training plan for Justyna:
#
# **Phase 1: Building Foundation (Weeks 1-4)**
#
# * **Day 1**
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Back Squats: 3 sets of 10-12 reps
# 	+ Leg Press: 3 sets of 10-12 reps
# 	+ Single Leg Extensions: 3 sets of 10-12 reps (per leg)
# * **Day 2**
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Lat Pulldown: 3 sets of 10-12 reps
# 	+ Bench Press: 3 sets of 10-12 reps
# 	+ Back Extensions: 3 sets of 10-12 reps
# * **Day 3**
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Deadlifts: 3 sets of 10-12 reps
# 	+ Leg Press: 2 sets of 10-12 reps (per leg)
# 	+ Hip Abductions: 2 sets of 10-12 reps
#
# **Phase 2: Building Strength and Endurance (Weeks 5-8)**
#
# * **Day 1**
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Back Squats: 3 sets of 12-15 reps
# 	+ Leg Press: 3 sets of 12-15 reps
# 	+ Single Leg Extensions: 3 sets of 12-15 reps (per leg)
# * **Day 2**
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Lat Pulldown: 3 sets of 12-15 reps
# 	+ Bench Press: 3 sets of 12-15 reps
# 	+ Back Extensions: 3 sets of 12-15 reps
# * **Day 3**
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Deadlifts: 2 sets of 15-20 reps
# 	+ Leg Press: 2 sets of 15-20 reps
# 	+ Hip Abductions: 2 sets of 15-20 reps
#
# **Phase 3: Increasing Intensity and Hypertrophy (Weeks 9-12)**
#
# * **Day 1**
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Back Squats: 4 sets of 8-10 reps
# 	+ Leg Press: 4 sets of 8-10 reps
# 	+ Single Leg Extensions: 3 sets of 8-10 reps (per leg)
# * **Day 2**
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Lat Pulldown: 3 sets of 8-10 reps
# 	+ Bench Press: 4 sets of 8-10 reps
# 	+ Back Extensions: 3 sets of 8-10 reps
# * **Day 3**
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Deadlifts: 2 sets of 12-15 reps
# 	+ Leg Press: 2 sets of 12-15 reps
# 	+ Hip Abductions: 2 sets of 12-15 reps
#
# **Phase 4: Increasing Intensity and Peak Performance (Weeks 13-16)**
#
# * **Day 1**
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Back Squats: 3 sets of 10-12 reps
# 	+ Leg Press: 3 sets of 10-12 reps
# 	+ Single Leg Extensions: 3 sets of 10-12 reps (per leg)
# * **Day 2**
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Lat Pulldown: 3 sets of 8-10 reps
# 	+ Bench Press: 4 sets of 6-8 reps
# 	+ Back Extensions: 3 sets of 8-10 reps
# * **Day 3**
# 	+ Warm-up: 5-minute dynamic stretching
# 	+ Deadlifts: 2 sets of 15-20 reps
# 	+ Leg Press: 2 sets of 15-20 reps
# 	+ Hip Abductions: 2 sets of 15-20 reps
#
# **Additional Recommendations**
#
# * Incorporate rest days as needed, but aim for at least one day per week.
# * Increase cardio exercises such as running or cycling to improve cardiovascular endurance.
# * Consider adding flexibility and mobility exercises to maintain range of motion and prevent injury.
#
# **Progress Tracking**
#
# * Monitor Justyna's progress through regular workouts and adjustments to the plan based on her performance.
# * Take body measurements, track weight, and note improvements in strength and endurance.
#
# By following this personalized training plan, Justyna can work towards building a strong foundation, increasing strength and endurance, and preparing for peak performance.
#
# ========================================
# Training Plan for Florida Ahmed
# ========================================
# Based on the user's information, I'll create a personalized training plan that addresses their goals, fitness level, and current situation.
#
# **Personalized Training Plan:**
#
# **User Profile:**
#
# * Name: Florida Ahmed
# * Age: 26
# * Gender: Female
# * Height (cm): 158.0
# * Weight (kg): 63
# * Goal 1: Weight Loss
# * Goal 2: Enhance flexibility and mobility
# * Goal 3: Tone and sculpt the body
# * Fitness Level: Intermediate
# * Workout Frequency: 5 days/week, 90 minutes per session
# * Workout Location: Gym
# * Equipment Available: None ( Home workout)
# * Injury Medical Condition: Knee ligament injury
#
# **Phase 1: Foundation Building (Weeks 1-4)**
#
# * Goal: Build overall strength and muscle mass
# * Workout Routine:
# 	+ Monday (Chest and Triceps):
# 		- Barbell Bench Press (3 sets, 10-12 reps)
# 		- Incline Dumbbell Press (3 sets, 10-12 reps)
# 		- Cable Flyes (3 sets, 12-15 reps)
# 	+ Tuesday (Back and Biceps):
# 		- Deadlifts (3 sets, 10-12 reps)
# 		- Bent-Over Barbell Rows (3 sets, 10-12 reps)
# 		- Dumbbell Bicep Curls (3 sets, 10-12 reps)
# 	+ Wednesday (Rest Day)
# 	+ Thursday (Legs):
# 		- Squats (3 sets, 10-12 reps)
# 		- Leg Press (3 sets, 10-12 reps)
# 		- Lunges (3 sets, 10-12 reps per leg)
# 	+ Friday (Shoulders and Abs):
# 		- Shoulder Press (3 sets, 10-12 reps)
# 		- Lateral Raises (3 sets, 10-12 reps)
# 		- Planks (3 sets, 30-60 seconds)
#
# **Phase 2: Hypertrophy (Weeks 5-8)**
#
# * Goal: Increase muscle mass and definition
# * Workout Routine:
# 	+ Monday (Chest and Triceps):
# 		- Incline Dumbbell Press (3 sets, 12-15 reps)
# 		- Cable Flyes (3 sets, 15-18 reps)
# 		- Chest Dips (3 sets, 10-12 reps)
# 	+ Tuesday (Back and Biceps):
# 		- Pull-Ups (or Assisted Pull-Ups) (3 sets, 10-12 reps)
# 		- Barbell Rows (3 sets, 12-15 reps)
# 		- Hammer Curls (3 sets, 10-12 reps)
# 	+ Wednesday (Rest Day)
# 	+ Thursday (Legs):
# 		- Squats (3 sets, 12-15 reps)
# 		- Leg Press (3 sets, 12-15 reps)
# 		- Lunges (3 sets, 12-15 reps per leg)
# 	+ Friday (Shoulders and Abs):
# 		- Lateral Raises (3 sets, 10-12 reps)
# 		- Rear Delt Flyes (3 sets, 12-15 reps)
# 		- Planks (3 sets, 30-60 seconds)
#
# **Phase 3: Strength Building (Weeks 9-12)**
#
# * Goal: Increase overall strength and power
# * Workout Routine:
# 	+ Monday (Chest and Triceps):
# 		- Incline Dumbbell Press (3 sets, 15-18 reps)
# 		- Cable Flyes (3 sets, 18-20 reps)
# 		- Chest Extensions (3 sets, 12-15 reps)
# 	+ Tuesday (Back and Biceps):
# 		- Deadlifts (3 sets, 15-18 reps)
# 		- Bent-Over Barbell Rows (3 sets, 15-18 reps)
# 		- Dumbbell Bicep Curls (3 sets, 12-15 reps)
# 	+ Wednesday (Rest Day)
# 	+ Thursday (Legs):
# 		- Squats (3 sets, 18-20 reps)
# 		- Leg Press (3 sets, 18-20 reps)
# 		- Lunges (3 sets, 18-20 reps per leg)
# 	+ Friday (Shoulders and Abs):
# 		- Shoulder Press (3 sets, 15-18 reps)
# 		- Lateral Raises (3 sets, 12-15 reps)
# 		- Planks (3 sets, 30-60 seconds)
#
# **Phase 4: Finishing Phase (Weeks 13-16)**
#
# * Goal: Maintain strength and muscle mass
# * Workout Routine:
# 	+ Monday (Chest and Triceps):
# 		- Incline Dumbbell Press (3 sets, 12-15 reps)
# 		- Cable Flyes (3 sets, 15-18 reps)
# 		- Chest Extensions (3 sets, 10-12 reps)
# 	+ Tuesday (Back and Biceps):
# 		- Pull-Ups (or Assisted Pull-Ups) (3 sets, 10-12 reps)
# 		- Barbell Rows (3 sets, 12-15 reps)
# 		- Hammer Curls (3 sets, 10-12 reps)
# 	+ Wednesday (Rest Day)
# 	+ Thursday (Legs):
# 		- Squats (3 sets, 18-20 reps)
# 		- Leg Press (3 sets, 18-20 reps)
# 		- Lunges (3 sets, 18-20 reps per leg)
# 	+ Friday (Shoulders and Abs):
# 		- Lateral Raises (3 sets, 12-15 reps)
# 		- Rear Delt Flyes (3 sets, 10-12 reps)
# 		- Planks (3 sets, 30-60 seconds)
#
# **Progressive Overload:**
#
# * Increase weight by 2.5-5kg (5-10lbs) every two weeks
# * Increase reps by 1-2 every two weeks
#
# **Nutrition:**
#
# * Caloric intake: 2500-2800 calories/day
# * Protein intake: 120-150g/day
# * Carbohydrates: 200-250g/day
# * Fat: 70-80g/day
#
# **Supplementation:**
#
# * Protein powder (20-25g/day)
# * Creatine monohydrate (3-5g/day)
#
# This plan assumes that Florida will continue to work out 5 days a week, 90 minutes per session. She should aim to increase the weight by 2.5-5kg every two weeks and increase reps by 1-2 every two weeks. Nutrition and supplementation plans can be adjusted based on individual needs and progress.
#
# ========================================
# Training Plan for Shrenik Vaidya
# ========================================
# Based on the provided information, I'll create a personalized training plan for Shrenik Vaidya.
#
# **Training Goals:**
#
# * Weight Loss
# * Building muscle strength
# * Stress relief and mental well-being
# * Increasing energy levels
# * Toning and sculpting the body (full-body)
#
# **Current Fitness Level:** Beginner
#
# **Workout Schedule:**
#
# * 4 days per week, with each day consisting of a combination of strength training and cardio exercises.
#
# **Workout Plan:**
#
# **Day 1: Chest and Triceps**
#
# 1. Warm-up: 5-10 minutes on the treadmill or stationary bike
# 2. Barbell Bench Press: 3 sets of 8-12 reps
# 	* Focus on proper form and engaging your triceps throughout the movement.
# 3. Incline Dumbbell Press: 3 sets of 10-15 reps
# 4. Tricep Pushdown: 3 sets of 10-12 reps
# 5. Overhead Dumbbell Extension: 3 sets of 12-15 reps
# 6. Cool-down: 5-10 minutes of stretching
#
# **Day 2: Back and Biceps**
#
# 1. Warm-up: 5-10 minutes on the treadmill or stationary bike
# 2. Pull-ups (or Assisted Pull-ups): 3 sets of as many reps as possible
# 	* Focus on squeezing your lats at the top of the movement.
# 3. Barbell Rows: 3 sets of 8-12 reps
# 4. Dumbbell Bicep Curls: 3 sets of 10-12 reps
# 5. Hammer Curls (with dumbbells): 3 sets of 10-12 reps
# 6. Cool-down: 5-10 minutes of stretching
#
# **Day 3: Legs**
#
# 1. Warm-up: 5-10 minutes on the treadmill or stationary bike
# 2. Squats: 3 sets of 8-12 reps
# 	* Focus on proper form and engaging your glutes throughout the movement.
# 3. Leg Press: 3 sets of 10-12 reps
# 4. Lunges: 3 sets of 10-12 reps (per leg)
# 5. Leg Extensions: 3 sets of 12-15 reps
# 6. Cool-down: 5-10 minutes of stretching
#
# **Day 4: Shoulders and Abs**
#
# 1. Warm-up: 5-10 minutes on the treadmill or stationary bike
# 2. Seated Dumbbell Shoulder Press: 3 sets of 8-12 reps
# 	* Focus on squeezing your shoulders at the top of the movement.
# 3. Lateral Raises: 3 sets of 10-12 reps
# 4. Reverse Fly (with dumbbells): 3 sets of 12-15 reps
# 5. Plank: 3 sets, holding for as long as possible
# 6. Russian Twists (with dumbbells): 3 sets of 10-12 reps
# 7. Cool-down: 5-10 minutes of stretching
#
# **Cardio Exercises**
#
# * 30-45 minutes of steady-state cardio per session, 2-3 times per week.
# * Examples:
# 	+ Jogging or running on a treadmill
# 	+ Cycling on a stationary bike
# 	+ Swimming or rowing exercises
# 	+ High-intensity interval training (HIIT)
#
# **Additional Tips:**
#
# * Start with lighter weights and gradually increase the load as you become stronger.
# * Focus on proper form and technique throughout each exercise.
# * Rest for 60-90 seconds between sets, and 120-180 seconds between exercises.
# * Increase cardio intensity and duration as you progress through the program.
#
# This personalized training plan is tailored to Shrenik Vaidya's fitness goals and preferences. It includes a mix of strength training and cardio exercises, with a focus on progressive overload and proper form.
#
# ========================================
# Training Plan for Katarzyna
# ========================================
# Here is a personalized training plan for Katarzyna based on her fitness goals, level of experience, and preferences:
#
# **Training Goals:**
#
# 1. Build muscle strength
# 2. Enhance flexibility and mobility
# 3. Stress relief and mental well-being (through gentle stretching and relaxation exercises)
#
# **Current Fitness Level:**
#
# * Intermediate: Having some basic knowledge of exercise routines and physical activities, but with room for improvement.
# * No prior experience with training plans or progressive overload.
#
# **Workout Schedule:**
#
# Katarzyna plans to work out 2 days a week. Here is her workout schedule:
#
# * Day 1:
# 	+ Warm-up (5 minutes): Light cardio (e.g., jogging in place, jumping jacks)
# 	+ Exercises:
# 		- Leg Press (3 sets of 10-12 reps)
# 		- Single Leg Ext (3 sets of 10-12 reps per leg)
# 		- Core exercises: Plank hold for 30 seconds to 1 minute, followed by 30 seconds of rest
# 	+ Cool-down (5 minutes): Static stretches for major muscle groups (e.g., hamstrings, quadriceps, chest, back)
#
# * Day 2:
# 	+ Warm-up (5 minutes): Light cardio (e.g., cycling, swimming)
# 	+ Exercises:
# 		- Back Squats (3 sets of 10-12 reps)
# 		- Lat Pulldown (3 sets of 10-12 reps)
# 		- Leg Press (3 sets of 10-12 reps)
# 		- Core exercises: Side plank hold for 30 seconds to 1 minute, followed by 30 seconds of rest
# 	+ Cool-down (5 minutes): Static stretches for major muscle groups
#
# **Progressive Overload:**
#
# * Increase the weight or resistance used in leg press and single leg extension exercises every two weeks.
#
# **Exercise Variation:**
#
# * Change exercise order and routine every four weeks to avoid stagnation.
# * Incorporate different types of cardio (e.g., low-Intensity Steady State, running/jogging) once a week.
#
# **Rest Periods:**
#
# * 2-3 minutes rest between sets for most exercises
# * 5-10 minutes rest between days
#
# **Additional Tips:**
#
# * Start with lighter weights and progress gradually.
# * Focus on proper form and technique over heavy lifting.
# * Listen to your body and take rest days as needed.
#
# Here is Katarzyna's personalized training plan:
#
# ```
#   -------------------------------
#   | User: [Name]                 |
#   |                              |
#   | Day 1                       |
#   | Exercises         Sets  Reps |
#   | Back Squats       3     10-12|
#   | Leg Press         3     10-12|
#   | Single Leg Ext    3     10-12|
#   | Warm-up (5 minutes)     |
#   | Cool-down (5 minutes)   |
#   -------------------------------
#   | Day 2                       |
#   | Exercises         Sets  Reps |
#   | Lat Pulldown      3     10-12|
#   | Bench Press       3     10-12|
#   | Back Ext          3     10-12|
#   | Warm-up (5 minutes)     |
#   | Cool-down (5 minutes)   |
#   -------------------------------
# ```
#
# This plan is tailored to Katarzyna's fitness goals, level of experience, and preferences. It includes a mix of strength training exercises, cardio activities, and flexibility and mobility exercises to help her achieve her goals.
#
# ========================================
# Training Plan for F
# ========================================
# Based on the provided user data, here's a personalized training plan tailored to their goals of building muscle strength, toning and sculpting the body, focusing on core development, glutes, posture, and alignment, with an 4-day split.
#
# **Training Plan**
#
# **Day 1: Full Body (Strength Focus)**
#
# 1. Warm-up:
# 	* 5-10 minutes of light cardio (jogging in place, jumping jacks)
# 	* Dynamic stretching for the major muscle groups
# 2. Exercises:
# 	* Squats: 3 sets of 10-12 reps
# 	* Deadlifts: 3 sets of 10-12 reps
# 	* Bench Press: 3 sets of 10-12 reps
# 	* Leg Press: 3 sets of 10-12 reps
# 	* Glute Bridges: 2 sets of 10-12 reps
# 	* Russian twists (light weights): 2 sets of 10-12 reps per side
# 3. Cool-down:
# 	* 5-10 minutes of stretching for the major muscle groups
#
# **Day 2: Core Focus**
#
# 1. Warm-up:
# 	* 5-10 minutes of light cardio (jogging in place, jumping jacks)
# 	* Dynamic stretching for the core muscles
# 2. Exercises:
# 	* Plank: hold for 30-60 seconds
# 	* Russian twists (light weights): 3 sets of 12 reps per side
# 	* Leg raises (hanging leg raise machine or bodyweight): 3 sets of 10-12 reps
# 	* Bicycle crunches: 3 sets of 10-12 reps
# 	* Woodchoppers (light weights): 2 sets of 12 reps per side
# 3. Cool-down:
# 	* 5-10 minutes of stretching for the core muscles
#
# **Day 3: Glutes Focus**
#
# 1. Warm-up:
# 	* 5-10 minutes of light cardio (jogging in place, jumping jacks)
# 	* Dynamic stretching for the gluteal muscles
# 2. Exercises:
# 	* Deadlifts: 3 sets of 10-12 reps
# 	* Hip Abduction: 2 sets of 10-12 reps per leg
# 	* Glute Bridges: 2 sets of 10-12 reps
# 	* Step-ups (using a low step or bench): 2 sets of 10-12 reps per leg
# 3. Cool-down:
# 	* 5-10 minutes of stretching for the gluteal muscles
#
# **Day 4: Full Body (Endurance Focus)**
#
# 1. Warm-up:
# 	* 5-10 minutes of light cardio (jogging in place, jumping jacks)
# 	* Dynamic stretching for the major muscle groups
# 2. Exercises:
# 	* Burpees: 3 sets of 8-10 reps
# 	* Mountain climbers: 3 sets of 30-60 seconds
# 	* Jumping lunges: 2 sets of 10-12 reps per leg
# 	* Squat jumps: 2 sets of 10-12 reps
# 3. Cool-down:
# 	* 5-10 minutes of stretching for the major muscle groups
#
# **Additional Tips**
#
# 1. Warm up properly before each workout and cool down afterwards to prevent injuries.
# 2. Rest for 60-90 seconds between sets, and 120-180 seconds between exercises.
# 3. Focus on proper form and technique throughout each exercise.
# 4. Increase the weight or reps as your body adapts to the training plan.
# 5. Include cardio activities (such as jogging, cycling, or rowing) 2-3 times per week for added benefits.
#
# **Sample Workout Log**
#
# | Day | Exercise | Sets | Reps |
# | --- | --- | --- | --- |
# | Day 1 | Squats | 3 | 10-12 |
# | Day 1 | Deadlifts | 3 | 10-12 |
# | Day 1 | Bench Press | 3 | 10-12 |
# | Day 1 | Leg Press | 3 | 10-12 |
# | Day 2 | Plank | 3 | 30-60 sec |
# | Day 2 | Russian twists | 3 | 12 reps per side |
# | Day 2 | Leg raises | 3 | 10-12 reps |
# | Day 2 | Bicycle crunches | 3 | 10-12 reps |
# | Day 2 | Woodchoppers | 2 | 12 reps per side |
# | Day 3 | Deadlifts | 3 | 10-12 |
# | Day 3 | Hip Abduction | 2 | 10-12 reps per leg |
# | Day 3 | Glute Bridges | 2 | 10-12 reps |
# | Day 3 | Step-ups | 2 | 10-12 reps per leg |
# | Day 4 | Burpees | 3 | 8-10 reps |
# | Day 4 | Mountain climbers | 3 | 30-60 sec |
# | Day 4 | Jumping lunges | 2 | 10-12 reps per leg |
#
# Remember to consult with a doctor or a certified personal trainer before starting any new exercise program.
#
# ========================================
# Training Plan for H
# ========================================
# Based on the provided information, I'll create a personalized training plan for the user. Please note that this plan should be adjusted according to the user's specific needs, goals, and progress.
#
# **Training Plan:**
#
# **User Information:**
#
# * Name: H
# * Age: 34
# * Gender: Female
# * Height (cm): 156.0
# * Weight (Kg): 55
#
# **Progressive Overload:**
#
# To avoid plateaus and ensure continued progress, we'll aim to increase the intensity in phases 2-4.
#
# * Phase 1: Intermediate level (Weeks 1-4)
# 	+ Goal: Build foundational muscle and strength
# * Phase 2: Intermediate-High level (Weeks 5-8)
# 	+ Goal: Increase overall strength, power, and endurance
# * Phase 3: High-Moderate level (Weeks 9-12)
# 	+ Goal: Focus on peak performance and maximum strength
# * Phase 4: Moderate-Low level (Weeks 13-16)
# 	+ Goal: Refine muscle tone and balance
#
# **Training Program:**
#
# **Day 1: Chest and Triceps**
#
# * Exercises:
# 	+ Barbell Bench Press (3 sets, 10-12 reps)
# 	+ Incline Dumbbell Press (3 sets, 10-12 reps)
# 	+ Cable Flyes (3 sets, 12-15 reps)
# 	+ Tricep Pushdowns (3 sets, 10-12 reps)
# * Warm-up: 5-minute dynamic stretching
# * Cool-down: 5-minute static stretching
#
# **Day 2: Back and Biceps**
#
# * Exercises:
# ...
# | Thursday | Cardio Day | - | - |
# | Friday | Chest and Triceps | 3 sets, 10-12 reps |  |
#
# This plan provides a structured approach to building muscle strength, increasing energy levels, and toning the body. Remember to listen to your body and adjust the plan as needed to avoid injury or discomfort.
#
# ========================================
# Training Plan for Udi
# ========================================
# Based on the user's data, I've created a personalized training plan that addresses their goals of enhancing flexibility and mobility, stress relief, and mental well-being.
#
# **Training Plan:**
#
# **Goal:** Enhance flexibility and mobility, while reducing stress and improving mental well-being.
#
# **User Profile:**
#
# * Name: Udi
# * Age: 39
# * Gender: Male
# * Height (cm): 178.0
# * Weight (Kg): 63
# * Fitness Level: Intermediate
# * Workout Frequency: 3 days/week
# * Workout Time: 60 minutes per session
#
# **Training Schedule:**
#
# Monday (Cardio Day):
#
# * Warm-up: 10-minute light cardio (jogging in place, jumping jacks, etc.)
# * High-Intensity Interval Training (HIIT):
# 	+ Run for 20 minutes at a moderate pace
# 	+ Rest for 2 minutes between intervals
# 	+ Repeat for 8 rounds
# * Cool-down: 5-minute stretching
#
# Tuesday (Upper Body Strength and Flexibility):
#
# * Warm-up: 10-minute light cardio (jogging in place, jumping jacks, etc.)
# * Resistance Training:
# 	+ Bicep Curls with Light Weights: 3 sets of 12 reps
# 	+ Tricep Dips: 3 sets of 12 reps
# 	+ Shoulder Press: 3 sets of 12 reps
# 	+ Chest Flys: 3 sets of 12 reps
# * Cool-down: 5-minute stretching
#
# Wednesday (Rest Day)
#
# Thursday (Lower Body Strength and Flexibility):
#
# * Warm-up: 10-minute light cardio (jogging in place, jumping jacks, etc.)
# * Resistance Training:
# 	+ Squats with Light Weights: 3 sets of 12 reps
# 	+ Lunges: 3 sets of 12 reps per leg
# 	+ Calf Raises: 3 sets of 12 reps
# 	+ Leg Press: 3 sets of 10-12 reps
# * Cool-down: 5-minute stretching
#
# Friday (Cardio Day):
#
# * Warm-up: 10-minute light cardio (jogging in place, jumping jacks, etc.)
# * HIIT:
# 	+ Run for 20 minutes at a moderate pace
# 	+ Rest for 2 minutes between intervals
# 	+ Repeat for 8 rounds
# * Cool-down: 5-minute stretching
#
# **Additional Recommendations:**
#
# 1. Incorporate activities that promote stress relief and mental well-being, such as yoga or meditation.
# 2. Consider incorporating foam rolling or self-myofascial release techniques to improve muscle mobility and reduce muscle tension.
# 3. Gradually increase the intensity and duration of workouts over time to avoid plateaus.
#
# **Example Training Plan:**
#
# Here's an example training plan that incorporates the above activities:
#
# ```
# -------------------------------
# | Day 1                       |
# | Exercises         Sets  Reps |
# | Chest Press      4     8-10|
# | Lat Pulldown   3     8-10|
# | Shoulder Press  3    12-15|
# | Tricep Dips   3    10-12|
# | Cool-down: 5-minute stretching |
#
# -------------------------------
# | Day 2                       |
# | Exercises         Sets  Reps |
# | Bicep Curls      4     8-10|
# | Leg Press        3     10-12|
# | Single Leg Ext  3    10-12|
# | Cool-down: 5-minute stretching |
#
# -------------------------------
# | Day 3                       |
# | Exercises         Sets  Reps |
# | Squats           3     10-12|
# | Lunges          3     10-12|
# | Calf Raises      3    10-12|
# | Hip Abduction   2     8-10|
# | Cool-down: 5-minute stretching |
#
# -------------------------------
# | Day 4                       |
# | Exercises         Sets  Reps |
# | Deadlifts        3    8-10|
# | Leg Press        3    10-12|
# | Chest Flys       3    8-10|
# | Cool-down: 5-minute stretching |
# ```
#
# This training plan is tailored to Udi's fitness level and goals, while incorporating a mix of strength training, cardio, and flexibility exercises. Remember to adjust the intensity and volume of workouts based on Udi's progress and comfort level.
#
# ========================================
# Training Plan for Monika
# ========================================
# Based on the user's data and fitness goals, I've created a personalized training plan for Monika. Since she's an intermediate female athlete with a focus on toning and sculpting her body, I've included a mix of compound exercises, isolation work, and cardio.
#
# **Week 1**
#
# * Day 1:
# 	+ Warm-up: 5-minute dynamic stretching (leg swings, arm circles)
# 	+ Squats: 3 sets of 10-12 reps
# 	+ Leg Press: 3 sets of 10-12 reps
# 	+ Seated Leg Extensions: 3 sets of 10-12 reps
# 	+ Planks: 3 sets of 30-second hold
# * Day 2:
# 	+ Warm-up: 5-minute dynamic stretching (leg swings, arm circles)
# 	+ Lat Pulldowns: 3 sets of 10-12 reps
# 	+ Seated Row: 3 sets of 10-12 reps
# 	+ Leg Curls: 3 sets of 10-12 reps
# 	+ Russian Twists: 3 sets of 10-12 reps (per side)
# * Day 3:
# 	+ Warm-up: 5-minute dynamic stretching (leg swings, arm circles)
# 	+ Deadlifts: 3 sets of 10-12 reps
# 	+ Leg Press: 3 sets of 10-12 reps
# 	+ Hip Abductions: 2 sets of 10-12 reps (per leg)
#
# **Week 2**
#
# * Day 1:
# 	+ Warm-up: 5-minute dynamic stretching (leg swings, arm circles)
# 	+ Bench Press: 3 sets of 10-12 reps
# 	+ Incline Dumbbell Press: 3 sets of 10-12 reps
# 	+ Tricep Pushdowns: 3 sets of 10-12 reps
# 	+ Bicep Curls: 3 sets of 10-12 reps
# * Day 2:
# 	+ Warm-up: 5-minute dynamic stretching (leg swings, arm circles)
# 	+ Chest Press: 3 sets of 10-12 reps
# 	+ Seated Cable Rows: 3 sets of 10-12 reps
# 	+ Leg Curls: 3 sets of 10-12 reps
# 	+ Reverse Flys: 3 sets of 10-12 reps (per side)
# * Day 3:
# 	+ Warm-up: 5-minute dynamic stretching (leg swings, arm circles)
# 	+ Pull-ups or Lat Pulldowns: 3 sets of 8-10 reps
# 	+ Seated Leg Extensions: 3 sets of 10-12 reps
# 	+ Russian Twists: 3 sets of 10-12 reps (per side)
#
# **Week 3**
#
# * Day 1:
# 	+ Warm-up: 5-minute dynamic stretching (leg swings, arm circles)
# 	+ Deadlifts: 3 sets of 8-10 reps
# 	+ Leg Press: 3 sets of 8-10 reps
# 	+ Glute Bridges: 3 sets of 10-12 reps
# 	+ Calf Raises: 3 sets of 10-12 reps
# * Day 2:
# 	+ Warm-up: 5-minute dynamic stretching (leg swings, arm circles)
# 	+ Bench Press: 3 sets of 8-10 reps
# 	+ Incline Dumbbell Press: 3 sets of 8-10 reps
# 	+ Tricep Pushdowns: 3 sets of 8-10 reps
# 	+ Bicep Curls: 3 sets of 8-10 reps
# * Day 3:
# 	+ Warm-up: 5-minute dynamic stretching (leg swings, arm circles)
# 	+ Pull-ups or Lat Pulldowns: 3 sets of 6-8 reps
# 	+ Seated Cable Rows: 3 sets of 8-10 reps
# 	+ Leg Curls: 3 sets of 8-10 reps
#
# **Week 4**
#
# * Day 1:
# 	+ Warm-up: 5-minute dynamic stretching (leg swings, arm circles)
# 	+ Deadlifts: 3 sets of 6-8 reps
# 	+ Leg Press: 3 sets of 6-8 reps
# 	+ Hip Abductions: 2 sets of 10-12 reps (per leg)
# * Day 2:
# 	+ Warm-up: 5-minute dynamic stretching (leg swings, arm circles)
# 	+ Bench Press: 3 sets of 6-8 reps
# 	+ Incline Dumbbell Press: 3 sets of 6-8 reps
# 	+ Tricep Pushdowns: 3 sets of 6-8 reps
# 	+ Bicep Curls: 3 sets of 6-8 reps
# * Day 3:
# 	+ Warm-up: 5-minute dynamic stretching (leg swings, arm circles)
# 	+ Pull-ups or Lat Pulldowns: 3 sets of 4-6 reps
# 	+ Seated Cable Rows: 3 sets of 8-10 reps
# 	+ Leg Curls: 3 sets of 6-8 reps
#
# **Cardio**
#
# * Aim for 150 minutes of moderate-intensity cardio per week, spread out over 3 days. This can be achieved with activities such as:
# 	+ Brisk walking
# 	+ Jogging or running
# 	+ Cycling
# 	+ Swimming
# 	+ High-Intensity Interval Training (HIIT)
#
# **Progressive Overload**
#
# * Increase the weight you lift by 2.5-5kg every two weeks, or as soon as you feel you can handle more.
# * Aim to increase your reps by 1-2 per week.
#
# **Note**
#
# * Make sure to warm up properly before each workout and cool down afterwards to prevent injury.
# * Rest for 60-90 seconds between sets and 120-180 seconds between exercises.
# * Adjust the weights, reps, and exercises based on your progress and fitness level.
#
# Remember, this is just a sample plan, and you should consult with a doctor or certified personal trainer before starting any new exercise program.
#
# ========================================
# Training Plan for Shayan
# ========================================
# Based on the provided information, I'll create a personalized training plan for Shayan. Since he has an advanced fitness level, I'll tailor the program to focus on building muscle strength, enhancing flexibility and mobility, and stress relief.
#
# **Assumptions:**
#
# * Shayan's daily activity is home-based (e.g., remote work or studying from home).
# * He's working out 2 days per week.
# * He has no specific areas of the body he wants to focus on beyond overall balance and strength.
#
# **Training Plan:**
#
# **Day 1: Chest and Triceps**
#
# 1. Warm-up:
# 	* 5-10 minutes of light cardio (jogging in place, jumping jacks, etc.)
# 2. Barbell Bench Press:
# 	* 3 sets of 8-12 reps
# 	* Lie on a flat bench and press the bar to your chest
# 3. Incline Dumbbell Press:
# 	* 3 sets of 10-15 reps
# 	* Sit on an incline bench and press the dumbbells upwards
# 4. Tricep Pushdowns:
# 	* 3 sets of 10-12 reps
# 	* Hold a bar with your hands shoulder-width apart and lower it behind your head
# 5. Overhead Dumbbell Extension:
# 	* 3 sets of 10-12 reps
# 	* Stand with your feet shoulder-width apart and hold dumbbells overhead
# 6. Cool-down:
# 	* 5-10 minutes of stretching
#
# **Day 2: Back and Biceps**
#
# 1. Warm-up:
# 	* 5-10 minutes of light cardio (jogging in place, jumping jacks, etc.)
# 2. Deadlifts:
# 	* 3 sets of 8-12 reps
# 	* Stand with your feet shoulder-width apart and lift the bar to hip level
# 3. Bent-Over Barbell Rows:
# 	* 3 sets of 8-12 reps
# 	* Hold a bar with your hands shoulder-width apart and bend over at the waist
# 4. Dumbbell Bicep Curls:
# 	* 3 sets of 10-15 reps
# 	* Stand with your feet shoulder-width apart and hold dumbbells with your palms facing forward
# 5. Hammer Curls:
# 	* 3 sets of 10-12 reps
# 	* Stand with your feet shoulder-width apart and hold dumbbells with your palms facing towards your body
# 6. Cool-down:
# 	* 5-10 minutes of stretching
#
# **Day 3: Legs**
#
# 1. Warm-up:
# 	* 5-10 minutes of light cardio (jogging in place, jumping jacks, etc.)
# 2. Squats:
# 	* 3 sets of 8-12 reps
# 	* Stand with your feet shoulder-width apart and lower your body down into a squat
# 3. Leg Press:
# 	* 3 sets of 10-15 reps
# 	* Sit at a leg press machine and push the platform away from you
# 4. Lunges:
# 	* 3 sets of 10-12 reps (per leg)
# 	* Stand with your feet together and take a large step forward with one foot
# 5. Leg Extensions:
# 	* 3 sets of 12-15 reps
# 	* Sit at a leg extension machine and lift the weight up
# 6. Cool-down:
# 	* 5-10 minutes of stretching
#
# **Day 4: Shoulders and Abs**
#
# 1. Warm-up:
# 	* 5-10 minutes of light cardio (jogging in place, jumping jacks, etc.)
# 2. Standing Military Press:
# 	* 3 sets of 8-12 reps
# 	* Stand with your feet shoulder-width apart and press the weight straight up
# 3. Lateral Raises:
# 	* 3 sets of 10-12 reps
# 	* Stand with your feet shoulder-width apart and hold dumbbells at shoulder height
# 4. Reverse Flys:
# 	* 3 sets of 10-12 reps
# 	* Hold a dumbbell in each hand and press them out to the sides
# 5. Plank:
# 	* 3 sets, holding for 30-60 seconds each
# 6. Cool-down:
# 	* 5-10 minutes of stretching
#
# **Progressive Overload:**
#
# * Increase weight by 2.5-5kg every two weeks.
# * Decrease rest time between sets by 15-30 seconds.
#
# **Rest and Recovery:**
#
# * Rest for 60-90 seconds between sets.
# * Take a 10-minute break after each workout session.
#
# This training plan is tailored to Shayan's fitness goals, focuses on building muscle strength, enhancing flexibility and mobility, and stress relief. It also includes rest days and progressive overload to ensure he adapts to the program over time.
#
# ========================================
# Training Plan for Agnes
# ========================================
# Here's a personalized training plan for Agnes:
#
# **Training Plan for Agnes**
#
# **Goal:** Improve overall strength, build muscle mass in various areas of her body, enhance posture and alignment, and increase confidence.
#
# **Assumptions:**
#
# * Agnes is an intermediate-level fitness enthusiast with 3 days per week of workout sessions.
# * She works out at home using a gym equipment.
# * Her daily activity level is moderate to active.
#
# **Training Plan Structure:**
#
# The training plan will be divided into four phases, each focusing on specific goals:
#
# Phase 1 (Weeks 1-4): Foundation Building
#
# * Goal: Build overall strength and muscle mass
# * Workout Frequency: 3 days per week
# * Workout Duration: 60 minutes per session
# * Emphasis:
# 	+ Squats, leg press, deadlifts, bench press, rows, and lunges for compound exercises
# 	+ Focus on proper form and technique
#
# Example Workouts:
#
# Day 1:
#
# * Warm-up (10-15 minutes): Cardio (jogging, jumping jacks, etc.)
# * Back Squats (3 sets of 10-12 reps)
# * Leg Press (3 sets of 10-12 reps)
# * Single-Leg Extremity (3 sets of 10-12 reps per leg)
# * Cool-down (5-10 minutes): Stretching
#
# Day 2:
#
# * Warm-up (10-15 minutes): Cardio
# * Lat Pulldown (3 sets of 10-12 reps)
# * Bench Press (3 sets of 10-12 reps)
# * Back Ext (3 sets of 10-12 reps)
# * Cool-down (5-10 minutes): Stretching
#
# Day 3:
#
# * Warm-up (10-15 minutes): Cardio
# * Deadlifts (3 sets of 10-12 reps)
# * Leg Press (3 sets of 10-12 reps)
# * Hip Abduction (2 sets of 10-12 reps)
# * Cool-down (5-10 minutes): Stretching
#
# **Phase 2 (Weeks 5-8): Hypertrophy and Strength**
#
# * Goal: Enhance muscle mass, increase strength
# * Workout Frequency: 3 days per week
# * Workout Duration: 60 minutes per session
# * Emphasis:
# 	+ Increase weight or reps for hypertrophy exercises
# 	+ Incorporate isolation exercises to target specific muscle groups
#
# Example Workouts:
#
# Day 1:
#
# * Warm-up (10-15 minutes): Cardio
# * Back Squats (3 sets of 12 reps)
# * Leg Press (3 sets of 12 reps)
# * Single-Leg Extremity (3 sets of 12 reps per leg)
# * Hip Abduction (2 sets of 12 reps)
#
# Day 2:
#
# * Warm-up (10-15 minutes): Cardio
# * Lat Pulldown (3 sets of 12 reps)
# * Bench Press (3 sets of 12 reps)
# * Back Ext (3 sets of 12 reps)
# * Cool-down (5-10 minutes): Stretching
#
# Day 3:
#
# * Warm-up (10-15 minutes): Cardio
# * Deadlifts (3 sets of 12 reps)
# * Leg Press (3 sets of 12 reps)
# * Hip Abduction (2 sets of 12 reps)
#
# **Phase 3 (Weeks 9-12): Power and Endurance**
#
# * Goal: Increase power, endurance for high-intensity activities
# * Workout Frequency: 3 days per week
# * Workout Duration: 60 minutes per session
# * Emphasis:
# 	+ Incorporate explosive exercises to improve power
# 	+ Reduce rest time between sets and reps
#
# Example Workouts:
#
# Day 1:
#
# * Warm-up (10-15 minutes): Cardio
# * Back Squats (4 sets of 8 reps)
# * Leg Press (3 sets of 12 reps)
# * Single-Leg Extremity (2 sets of 10 reps per leg)
# * Cool-down (5-10 minutes): Stretching
#
# Day 2:
#
# * Warm-up (10-15 minutes): Cardio
# * Lat Pulldown (4 sets of 8 reps)
# * Bench Press (3 sets of 12 reps)
# * Back Ext (3 sets of 12 reps)
# * Cool-down (5-10 minutes): Stretching
#
# Day 3:
#
# * Warm-up (10-15 minutes): Cardio
# * Deadlifts (4 sets of 6 reps)
# * Leg Press (2 sets of 12 reps)
# * Hip Abduction (1 set of 8 reps)
#
# **Phase 4 (Weeks 13-16): Specific Focus**
#
# * Goal: Enhance posture and alignment, increase confidence
# * Workout Frequency: 3 days per week
# * Workout Duration: 60 minutes per session
# * Emphasis:
# 	+ Focus on core exercises to improve posture and stability
# 	+ Incorporate high-intensity interval training (HIIT) for increased strength and endurance
#
# Example Workouts:
#
# Day 1:
#
# * Warm-up (10-15 minutes): Cardio
# * Core Plank (3 sets of 30-60 seconds)
# * Russian Twists (3 sets of 12 reps per side)
# * Leg Raises (3 sets of 12 reps)
# * Cool-down (5-10 minutes): Stretching
#
# Day 2:
#
# * Warm-up (10-15 minutes): Cardio
# * Lat Pulldown (4 sets of 8 reps)
# * Bench Press (3 sets of 12 reps)
# * Back Ext (3 sets of 12 reps)
# * Cool-down (5-10 minutes): Stretching
#
# Day 3:
#
# * Warm-up (10-15 minutes): Cardio
# * Deadlifts (4 sets of 6 reps)
# * Leg Press (2 sets of 12 reps)
# * Hip Abduction (1 set of 8 reps)
#
# **Additional Tips:**
#
# * Incorporate progressive overload by increasing weight or reps over time.
# * Focus on proper form and technique throughout each workout.
# * Listen to Agnes's body and adjust the training plan as needed.
# * Include rest days in the schedule to allow for recovery.
#
# By following this training plan, Agnes can expect to improve her overall strength, muscle mass, posture, and confidence. Remember to stay consistent, patient, and flexible, and she will achieve her fitness goals in no time!

# %%
def simplify_csv(file_path):
    # Load the CSV file
    data = pd.read_csv(file_path)
    
    # Clean and simplify column names
    data.columns = data.columns.str.strip().str.replace("\n", " ").str[:50]  # Limit column name length
    return data

simplified_data = simplify_csv('user_training_plans.csv')
simplified_data.to_csv('simplified_user_training_plans.csv', index=False)

# %%
plans = pd.read_csv('user_training_plans.csv')
print(plans.columns)
# Out:
# Index(['Timestamp', 'Name ', 'Age', 'Gender', 'Height (cm)', 'Weight (Kg)',
#        'What are your fitness goals? (You can select multiple options) ',
#        'How would you rate your fitness level?',
#        'How many days per week are you planning to working out?',
#        'How much time can you dedicate to each workout session?',
#        'Where are you planning to work out?',
#        'if you answered Home or mix, what equipment do you have available?',
#        'Do you have any specific areas of the body you want to focus on?',
#        'Would you like to include cardio in your fitness program?\nIf yes, please select the type(s) of cardio you are interested in:',
#        'What is your daily activity?',
#        'Do you have any injury or medical condition?',
#        'If you answered yes to above question, please provide a short description.',
#        'Training_Plan'],
#       dtype='object')
